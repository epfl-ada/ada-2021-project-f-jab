# %%
import os
import glob
import bz2
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
from collections import defaultdict

# %%
# Specifying filename and directory
data_dir = os.getcwd() + '\data'
quotebank_dir = data_dir + "\Quotebank"
quotebank_bz2 = os.listdir(quotebank_dir)

# Change directory
os.chdir(quotebank_dir)

# %%
df = pd.DataFrame()
for year_file in tqdm(quotebank_bz2):
    temp =  pd.read_json(year_file, lines=True, compression='bz2')
    df = pd.concat([df, temp], ignore_index = True)
        
df.shape
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# (52491, 10)

# %%
df.head()
# Out:
#              quoteID                                          quotation  \
# 0  2015-02-14-007911  For fans of the book they know that Effie's ro...
# 1  2015-11-15-027947                       Is Ferguson like Mockingjay?
# 2  2015-04-26-028061  It's pretty exciting-I have to say. I saw the ...
# 3  2015-12-31-028469  I want to clarify my interview on the `Charlie...
# 4  2015-10-07-077176  One area where we saw continued problems is Os...
#
#          speaker                qids                date  numOccurrences  \
# 0           None                  [] 2015-02-14 00:47:05               1
# 1     Laci Green         [Q16843606] 2015-11-15 03:15:53               1
# 2           None                  [] 2015-04-26 11:56:10               2
# 3   George Lucas  [Q1507803, Q38222] 2015-12-31 16:48:00               7
# 4  Rachel Gordon          [Q7279255] 2015-10-07 14:30:43               1
#
#                                               probas  \
# 0  [[None, 0.8008], [Francis Lawrence, 0.1299], [...
# 1             [[Laci Green, 0.9013], [None, 0.0987]]
# 2  [[None, 0.8589], [Jared Leto, 0.0772], [Joss W...
# 3  [[George Lucas, 0.5327], [None, 0.4248], [Char...
# 4  [[Rachel Gordon, 0.7129], [None, 0.2673], [Mar...
#
#                                                 urls phase  \
# 0  [http://www.buzzfeed.com/kristinharris/secrets...     E
# 1  [http://www.dailykos.com/story/2015/11/15/1450...     E
# 2  [http://ign.com/articles/2015/04/24/joss-whedo...     E
# 3  [http://www.escapistmagazine.com/news/view/165...     E
# 4  [http://missionlocal.org/2015/10/sf-gets-more-...     E
#
#                                         movie
# 0       The Hunger Games: Mockingjay - Part 2
# 1       The Hunger Games: Mockingjay - Part 2
# 2  Star Wars: Episode VII - The Force Awakens
# 3  Star Wars: Episode VII - The Force Awakens
# 4          Mission: Impossible - Rogue Nation

# %% [markdown]
# Removing NaN-values. We see that these only occur in the `movie` attribute which right now is due to an issue in the data filtering.

# %%
df.isnull().any()
# Out:
# quoteID           False
# quotation         False
# speaker           False
# qids              False
# date              False
# numOccurrences    False
# probas            False
# urls              False
# phase             False
# movie              True
# dtype: bool

# %%
df = df.loc[-df.isnull().any(axis=1)]

# %%
df.shape
# Out:
# (51993, 10)

# %% [markdown]
# ### Dealing with the speakers

# %% [markdown]
# We investigate how many quotes does not have an obvious speaker and is denoted by 'None'. Turns out that it is approximately 38%.

# %%
number_none_speakers = len(df[df.speaker == 'None'])

print(f"'None'-speakers: {number_none_speakers}")
print(f"Total fraction of 'None'-speakers: {number_none_speakers / len(df)}")
# Out:
# 'None'-speakers: 19574
# Total fraction of 'None'-speakers: 0.37647375608254957

# %% [markdown]
# Even though the single speakers are not really important for answering our research questions, we choose to clean the data by chaning 'None'-speakers to the speaker with second highest probability from the `df.probas` attribute.
# <span style="color:red"> *TODO*: THIS MIGHT NEED RE-ENGENEERING TO A MORE EXCLUSIVE THING. right now trump gets assigned to a lot. </span>

# %%
# Removes speaker as being None to being the second most likely in case speaker is 'None'
proba_threshhold = 0.15

secondary_speaker = [df['probas'][i][1][0] if (speaker == 'None') and (float(df['probas'][i][1][1]) > proba_threshhold) else speaker for i, speaker in enumerate(tqdm(df['speaker']))]
df['speaker'] = secondary_speaker
# Out:
#   0%|          | 0/51993 [00:00<?, ?it/s]

# %%
number_none_speakers = len(df[df.speaker == 'None'])

print(f"'None'-speakers: {number_none_speakers}")
print(f"Total fraction of 'None'-speakers: {number_none_speakers / len(df)}")
# Out:
# 'None'-speakers: 7696
# Total fraction of 'None'-speakers: 0.1480199257592368

# %%
df.head()
# Out:
#              quoteID                                          quotation  \
# 0  2015-02-14-007911  For fans of the book they know that Effie's ro...
# 1  2015-11-15-027947                       Is Ferguson like Mockingjay?
# 2  2015-04-26-028061  It's pretty exciting-I have to say. I saw the ...
# 3  2015-12-31-028469  I want to clarify my interview on the `Charlie...
# 4  2015-10-07-077176  One area where we saw continued problems is Os...
#
#          speaker                qids                date  numOccurrences  \
# 0           None                  [] 2015-02-14 00:47:05               1
# 1     Laci Green         [Q16843606] 2015-11-15 03:15:53               1
# 2           None                  [] 2015-04-26 11:56:10               2
# 3   George Lucas  [Q1507803, Q38222] 2015-12-31 16:48:00               7
# 4  Rachel Gordon          [Q7279255] 2015-10-07 14:30:43               1
#
#                                               probas  \
# 0  [[None, 0.8008], [Francis Lawrence, 0.1299], [...
# 1             [[Laci Green, 0.9013], [None, 0.0987]]
# 2  [[None, 0.8589], [Jared Leto, 0.0772], [Joss W...
# 3  [[George Lucas, 0.5327], [None, 0.4248], [Char...
# 4  [[Rachel Gordon, 0.7129], [None, 0.2673], [Mar...
#
#                                                 urls phase  \
# 0  [http://www.buzzfeed.com/kristinharris/secrets...     E
# 1  [http://www.dailykos.com/story/2015/11/15/1450...     E
# 2  [http://ign.com/articles/2015/04/24/joss-whedo...     E
# 3  [http://www.escapistmagazine.com/news/view/165...     E
# 4  [http://missionlocal.org/2015/10/sf-gets-more-...     E
#
#                                         movie
# 0       The Hunger Games: Mockingjay - Part 2
# 1       The Hunger Games: Mockingjay - Part 2
# 2  Star Wars: Episode VII - The Force Awakens
# 3  Star Wars: Episode VII - The Force Awakens
# 4          Mission: Impossible - Rogue Nation

# %% [markdown]
# Furthermore, we realize that there is a super specific timestamp on the `date` attribute. Later on we will match daily box office sales with the Quotebank data, so we strip the timestamps from the specific time of the date and focus solely on the date.

# %%
# Remove last part of date from the quoteID date string to be able to have an average daily sentiment score
reduced_dates = [("-").join(date.split("-")[:3]) for date in tqdm(df.quoteID)]
df['date'] = reduced_dates
# Out:
#   0%|          | 0/51993 [00:00<?, ?it/s]

# %%
df.head()
# Out:
#              quoteID                                          quotation  \
# 0  2015-02-14-007911  For fans of the book they know that Effie's ro...
# 1  2015-11-15-027947                       Is Ferguson like Mockingjay?
# 2  2015-04-26-028061  It's pretty exciting-I have to say. I saw the ...
# 3  2015-12-31-028469  I want to clarify my interview on the `Charlie...
# 4  2015-10-07-077176  One area where we saw continued problems is Os...
#
#          speaker                qids        date  numOccurrences  \
# 0           None                  []  2015-02-14               1
# 1     Laci Green         [Q16843606]  2015-11-15               1
# 2           None                  []  2015-04-26               2
# 3   George Lucas  [Q1507803, Q38222]  2015-12-31               7
# 4  Rachel Gordon          [Q7279255]  2015-10-07               1
#
#                                               probas  \
# 0  [[None, 0.8008], [Francis Lawrence, 0.1299], [...
# 1             [[Laci Green, 0.9013], [None, 0.0987]]
# 2  [[None, 0.8589], [Jared Leto, 0.0772], [Joss W...
# 3  [[George Lucas, 0.5327], [None, 0.4248], [Char...
# 4  [[Rachel Gordon, 0.7129], [None, 0.2673], [Mar...
#
#                                                 urls phase  \
# 0  [http://www.buzzfeed.com/kristinharris/secrets...     E
# 1  [http://www.dailykos.com/story/2015/11/15/1450...     E
# 2  [http://ign.com/articles/2015/04/24/joss-whedo...     E
# 3  [http://www.escapistmagazine.com/news/view/165...     E
# 4  [http://missionlocal.org/2015/10/sf-gets-more-...     E
#
#                                         movie
# 0       The Hunger Games: Mockingjay - Part 2
# 1       The Hunger Games: Mockingjay - Part 2
# 2  Star Wars: Episode VII - The Force Awakens
# 3  Star Wars: Episode VII - The Force Awakens
# 4          Mission: Impossible - Rogue Nation

# %% [markdown]
# The attribute `phase` seem to mostly take the values 'E'. The investigation below shows that all of the entries are in fact 'E' so we decide to remove it from the dataframe. From the documentation of the data we also do not find it relevant for our case. Also we won't be using the `quoteID` attribute but instead the WikiData compatible `qids`.

# %%
np.unique(df.phase, return_counts=True)
df = df.drop(['phase', 'quoteID'], axis=1)

# %% [markdown]
# ### Handling outliers in the numOccurrences

# %% [markdown]
# We want to check for outliers in the number of occurrences as it is the only numercal attribute left. By a first descriptive analysis of the variable we suspect something fishy as the maximum number is quite high. We note that there are no weird values on the other side as the minimum value of occurrences is 1.

# %%
df.numOccurrences.describe()
# Out:
# count    51993.000000
# mean         4.648337
# std        123.223533
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max      22903.000000
# Name: numOccurrences, dtype: float64

# %% [markdown]
# We also want to see if this seems unfeasible when looking at the plots. The boxplot reveals that there is a need to investigate outliers and the plot of the occurences reveal that the distribution seem to follow a strong power law. We will have to deal with outliers to get anything meaningful from the data.

# %%
plt.boxplot(df.numOccurrences)
plt.ylabel("Number of Occurrences")
plt.title("With outliers")
plt.show()

plt.hist(df.numOccurrences, bins=50)
plt.ylabel("Number of Occurrences")
plt.title("Histogram with outliers")
plt.show()

# %% [markdown]
# As a start we will investigate whether the IQR outlier removal approach is feasible for our data. The code is taken and re-written from our homework 1 hand-in.

# %%
def get_outliers(data):
    """ Filters out outliers that is more than 1.5 times lower than the 25% quantile and above 1.5 times higher than the 
    75% quantile.
    
    Input is the sub-dataframe consisting of the columns assosiacted with kilometrage data.
    returns the indeces for rows that contains outliers.
    
    Function idea is taken from our implementation in Homework 1
    
    """
    
    series = pd.Series(data)
    
    IQR = (series.quantile(0.75) - series.quantile(0.25)) 
    outlier_threshold = IQR * 1.5

    # calculating decision boundaries
    lower = series.quantile(0.25)-outlier_threshold
    upper = series.quantile(0.75)+outlier_threshold

    # Finds the union of outlier indeces from the previous column and the current column
    outlier_indeces = np.union1d(series.index[series < lower], series.index[series > upper])

    return np.array([int(x) for x in outlier_indeces])

# %%
outlier_ids = get_outliers(df.numOccurrences)
print(f"Number of IQR outliers: {len(outlier_ids)}")
print(f"Ratio of IQR outliers in original data: {len(outlier_ids)/len(df)}")
# Out:
# Number of IQR outliers: 7830
# Ratio of IQR outliers in original data: 0.1505971957763545

# %%
df = df.drop(outlier_ids)
df.index = np.arange(len(df))
df.shape
# Out:
# (44163, 8)

# %% [markdown]
# So 15% of the data was determined to be outliers based on the IQR range. We visualize the new distribution in the following.

# %%
df.describe()
# Out:
#        numOccurrences
# count    44163.000000
# mean         1.357788
# std          0.621381
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max          3.000000

# %%
plt.boxplot(df.numOccurrences)
plt.ylabel("Number of Occurrences for ID's")
plt.title("Without IQR outliers")
plt.show()

plt.hist(df.numOccurrences)
plt.ylabel("Number of Occurrences for ID's")
plt.title("Histogram Without IQR outliers")
plt.show()

# %%
df.head()
# Out:
#                                            quotation        speaker  \
# 0  For fans of the book they know that Effie's ro...           None
# 1                       Is Ferguson like Mockingjay?     Laci Green
# 2  It's pretty exciting-I have to say. I saw the ...           None
# 3  One area where we saw continued problems is Os...  Rachel Gordon
# 4  Is Daredevil joining the Avengers for Infinity...    Scott Davis
#
#           qids        date  numOccurrences  \
# 0           []  2015-02-14               1
# 1  [Q16843606]  2015-11-15               1
# 2           []  2015-04-26               2
# 3   [Q7279255]  2015-10-07               1
# 4           []  2015-12-10               2
#
#                                               probas  \
# 0  [[None, 0.8008], [Francis Lawrence, 0.1299], [...
# 1             [[Laci Green, 0.9013], [None, 0.0987]]
# 2  [[None, 0.8589], [Jared Leto, 0.0772], [Joss W...
# 3  [[Rachel Gordon, 0.7129], [None, 0.2673], [Mar...
# 4  [[None, 0.4806], [Scott Davis, 0.4017], [Antho...
#
#                                                 urls  \
# 0  [http://www.buzzfeed.com/kristinharris/secrets...
# 1  [http://www.dailykos.com/story/2015/11/15/1450...
# 2  [http://ign.com/articles/2015/04/24/joss-whedo...
# 3  [http://missionlocal.org/2015/10/sf-gets-more-...
# 4  [http://www.flickeringmyth.com/2015/12/is-dare...
#
#                                         movie
# 0       The Hunger Games: Mockingjay - Part 2
# 1       The Hunger Games: Mockingjay - Part 2
# 2  Star Wars: Episode VII - The Force Awakens
# 3          Mission: Impossible - Rogue Nation
# 4                     Avengers: Age of Ultron

# %% [markdown]
# ### Dealing with the quoter-IDs

# %% [markdown]
# Furthermore, we see that the `qids` might need some engineering. In the initial analyses on the 2019 NYT data we saw that some individuals are quoted differently even though it's in fact the same speaker. For instance this was the case for the speaker "Donald Trump" and "President Trump". In this case these two denotations share a common qID for which reason we would want to be able to get all quotes from Donald Trump and President Trump when searching for them independently. Even though it might not be as important with movies, we deem it good practice to regulate this behaviour. We start by engineering empty quoteID-lists as an unknown token.

# %%
empty = np.array([entry for entry, qID_list in enumerate(df.qids) if len(qID_list) == 0])
print(f"Number of currently unknown qids: {len(empty)}")
# Out:
# Number of currently unknown qids: 16487

# %%
pd.options.mode.chained_assignment = None
df['qids'][empty] = [['<UNK>']] * len(empty)

df.qids.head()
# Out:
# 0        [<UNK>]
# 1    [Q16843606]
# 2        [<UNK>]
# 3     [Q7279255]
# 4        [<UNK>]
# Name: qids, dtype: object

# %% [markdown]
# Using this '\<UNK>' token we are able to search the df to replace this token with a qID if the speaker occurs with a qID another place in the data. In this manner all qIDs of a specified speaker will be the full list of qIDs associated with that speaker.

# %%
def set_qID(speaker, df):
    #Extract qID's of a speaker
    qIDs = {speaker: list({quote_ID for quote_IDlist in df.qids[df['speaker'] == speaker] for quote_ID in quote_IDlist})}
    
    # Conditions for removing the <UNK> token.
    if len(qIDs[speaker]) > 1 and '<UNK>' in qIDs[speaker]:
        qIDs[speaker].remove('<UNK>')
    
    # Creating new qIDs for replacing in original dataframe
    speaker_indeces = np.where(df.speaker == speaker)[0]
    replacement = pd.Series([qIDs[speaker]] * (sum(df['speaker'] == speaker)), index=speaker_indeces)
    
    # Replace
    df.qids[df['speaker'] == speaker] = replacement

# %% [markdown]
# This now works, which can be seen on the speaker George Lucas in the following cells.

# %%
df[df.speaker == 'George Lucas'].head()
# Out:
#                                              quotation       speaker  \
# 22   When I started to go into Star Wars, [ my frie...  George Lucas
# 39   After `Star Wars,' I went back to Warner Bros....  George Lucas
# 67                               a Star Wars for girls  George Lucas
# 90   We became friends and then we started dating a...  George Lucas
# 113  I might use the lightsaber instead of a torch ...  George Lucas
#
#                    qids        date  numOccurrences  \
# 22   [Q1507803, Q38222]  2015-12-31               1
# 39   [Q1507803, Q38222]  2015-04-19               1
# 67              [<UNK>]  2015-01-27               1
# 90   [Q1507803, Q38222]  2015-12-19               2
# 113             [<UNK>]  2015-10-30               2
#
#                                                 probas  \
# 22   [[George Lucas, 0.7612], [Colin Trevorrow, 0.1...
# 39   [[George Lucas, 0.6949], [None, 0.1538], [Step...
# 67            [[None, 0.5037], [George Lucas, 0.4963]]
# 90            [[George Lucas, 0.5894], [None, 0.4106]]
# 113           [[None, 0.8296], [George Lucas, 0.1704]]
#
#                                                   urls  \
# 22   [http://theindianrepublic.com/i-sold-star-wars...
# 39   [http://sfgate.com/technology/businessinsider/...
# 67   [http://www.comicmix.com/2015/01/27/box-office...
# 90   [http://feeds.businessinsider.com.au/~/1290472...
# 113  [http://dailyliberal.com.au/story/3459543/movi...
#
#                                           movie
# 22   Star Wars: Episode VII - The Force Awakens
# 39   Star Wars: Episode VII - The Force Awakens
# 67   Star Wars: Episode VII - The Force Awakens
# 90   Star Wars: Episode VII - The Force Awakens
# 113  Star Wars: Episode VII - The Force Awakens

# %%
# Calling the function
set_qID('George Lucas', df)

df[df.speaker == 'George Lucas'].head()
# Out:
#                                              quotation       speaker  \
# 22   When I started to go into Star Wars, [ my frie...  George Lucas
# 39   After `Star Wars,' I went back to Warner Bros....  George Lucas
# 67                               a Star Wars for girls  George Lucas
# 90   We became friends and then we started dating a...  George Lucas
# 113  I might use the lightsaber instead of a torch ...  George Lucas
#
#                    qids        date  numOccurrences  \
# 22   [Q1507803, Q38222]  2015-12-31               1
# 39   [Q1507803, Q38222]  2015-04-19               1
# 67   [Q1507803, Q38222]  2015-01-27               1
# 90   [Q1507803, Q38222]  2015-12-19               2
# 113  [Q1507803, Q38222]  2015-10-30               2
#
#                                                 probas  \
# 22   [[George Lucas, 0.7612], [Colin Trevorrow, 0.1...
# 39   [[George Lucas, 0.6949], [None, 0.1538], [Step...
# 67            [[None, 0.5037], [George Lucas, 0.4963]]
# 90            [[George Lucas, 0.5894], [None, 0.4106]]
# 113           [[None, 0.8296], [George Lucas, 0.1704]]
#
#                                                   urls  \
# 22   [http://theindianrepublic.com/i-sold-star-wars...
# 39   [http://sfgate.com/technology/businessinsider/...
# 67   [http://www.comicmix.com/2015/01/27/box-office...
# 90   [http://feeds.businessinsider.com.au/~/1290472...
# 113  [http://dailyliberal.com.au/story/3459543/movi...
#
#                                           movie
# 22   Star Wars: Episode VII - The Force Awakens
# 39   Star Wars: Episode VII - The Force Awakens
# 67   Star Wars: Episode VII - The Force Awakens
# 90   Star Wars: Episode VII - The Force Awakens
# 113  Star Wars: Episode VII - The Force Awakens

# %% [markdown]
# We want to apply this functionality to the full dataframe (meaning all individual speakers) for which reason we extract the individual speaker names and how frequently quoted they are. We calculate the number of unique quotes for each speaker even though we find it more relevant to do outlier detection based on total number of occurences (`numOccurrences` attribute). This will be done later in the pipeline.

# %%
speakers, freq_unsorted = np.unique(df.speaker, return_counts=True)
freq, speakers = np.array(list(zip(*sorted(zip(freq_unsorted, speakers), reverse=True))))

print("Top 10 quoted speakers (w/o numOccurences): ")
list(zip(speakers[:10], freq[:10]))
# Out:
# Top 10 quoted speakers (w/o numOccurences):
# [('None', '6347'),
#  ('Kevin Feige', '932'),
#  ('Captain Marvel', '799'),
#  ('Joe Russo', '506'),
#  ('J.J. Abrams', '479'),
#  ('Bob Iger', '356'),
#  ('Tom Holland', '312'),
#  ('Kathleen Kennedy', '312'),
#  ('George Lucas', '288'),
#  ('Ryan Reynolds', '278')]

# %%
for speaker in tqdm(speakers):
    set_qID(speaker, df=df)
# Out:
#   0%|          | 0/11536 [00:00<?, ?it/s]

# %% [markdown]
# Now, the only way there would be qID's of the name '\<UNK>' would be if the assignment of the predicted speaker is less than 15% percent certain (see `proba_threshhold` in the removal of None-type speakers) and if that same speaker does not have a qID throughout all of the dataframe. In this case we find evidence for deleting the rows.

# %%
UNK_idxs = np.array([], dtype=int)
for i, qID in enumerate(tqdm(df.qids)):
    if '<UNK>' in qID:
        UNK_idxs = np.append(UNK_idxs, i)
# Out:
#   0%|          | 0/44163 [00:00<?, ?it/s]

# %%
df = df.drop(UNK_idxs)
df.index = np.arange(len(df))
df.shape
# Out:
# (34699, 8)

# %% [markdown]
# The following function then concatenates the qID's of speakers if they have more than one qID in common, such that we get exactly the basis for a shared ID if two speakers (like Donald Trump and President Trump) are in fact the same.

# %%
def mergeQuoteIDs(df):
    qID_dict = defaultdict(dict)
    print("Creating qID dictionary...")
    for document_number, qid_list in enumerate(tqdm(df.qids)):
        for qid in qid_list:
            if qid in qID_dict:
                qID_dict[qid].append(document_number)
            else:
                qID_dict[qid] = [document_number]
    
    print("Gathering qIDs across documents...")
    new_column = {}
    for document_number, qid_list in enumerate(tqdm(df.qids)):
        document_IDs = []
        for qid in qid_list:
            document_IDs.append(qID_dict[qid])

        related_docs = set(np.concatenate(document_IDs))
        new_qids = list(set(np.concatenate(list(df.qids[related_docs]))))

        new_column[document_number] = new_qids

    df['qids'] = pd.Series(new_column)

# %%
mergeQuoteIDs(df)
df.head()
# Out:
# Creating qID dictionary...
#   0%|          | 0/34699 [00:00<?, ?it/s]
# Gathering qIDs across documents...
#   0%|          | 0/34699 [00:00<?, ?it/s]
#                                            quotation        speaker  \
# 0                       Is Ferguson like Mockingjay?     Laci Green
# 1  One area where we saw continued problems is Os...  Rachel Gordon
# 2  Is Daredevil joining the Avengers for Infinity...    Scott Davis
# 3  Part 2: Solutions to Problems Facing The Afric...  David Cameron
# 4  They were saying, `Well, since when has Star W...    J.J. Abrams
#
#                                                 qids        date  \
# 0                                        [Q16843606]  2015-11-15
# 1                                         [Q7279255]  2015-10-07
# 2  [Q18202175, Q1373440, Q1259234, Q24005690, Q74...  2015-12-10
# 3  [Q1173911, Q18719363, Q5232111, Q16195447, Q19...  2015-10-03
# 4                                          [Q188137]  2015-12-21
#
#    numOccurrences                                             probas  \
# 0               1             [[Laci Green, 0.9013], [None, 0.0987]]
# 1               1  [[Rachel Gordon, 0.7129], [None, 0.2673], [Mar...
# 2               2  [[None, 0.4806], [Scott Davis, 0.4017], [Antho...
# 3               2  [[None, 0.7792], [David Cameron, 0.1805], [Eri...
# 4               1  [[J.J. Abrams, 0.5868], [None, 0.2584], [Lupit...
#
#                                                 urls  \
# 0  [http://www.dailykos.com/story/2015/11/15/1450...
# 1  [http://missionlocal.org/2015/10/sf-gets-more-...
# 2  [http://www.flickeringmyth.com/2015/12/is-dare...
# 3  [http://www.blogtalkradio.com/theafricanhistor...
# 4  [http://rssfeeds.usatoday.com/~/129385923/0/us...
#
#                                         movie
# 0       The Hunger Games: Mockingjay - Part 2
# 1          Mission: Impossible - Rogue Nation
# 2                     Avengers: Age of Ultron
# 3       The Hunger Games: Mockingjay - Part 2
# 4  Star Wars: Episode VII - The Force Awakens

# %% [markdown]
# And then we create a new ID for each unique list of qID's.

# %%
def newID(df):
    unique_IDlists = np.unique(df['qids'])
    newIDs = []
    
    for row_qIDlist in tqdm(df.qids):
        for newID, unique_list in enumerate(unique_IDlists):
            if unique_list == row_qIDlist:
                newIDs.append(newID)
    df['shared_ID'] = newIDs
    
    return newIDs

# %%
newIDs = newID(df)
# Out:
#   0%|          | 0/34699 [00:00<?, ?it/s]

# %%
df.head()
# Out:
#                                            quotation        speaker  \
# 0                       Is Ferguson like Mockingjay?     Laci Green
# 1  One area where we saw continued problems is Os...  Rachel Gordon
# 2  Is Daredevil joining the Avengers for Infinity...    Scott Davis
# 3  Part 2: Solutions to Problems Facing The Afric...  David Cameron
# 4  They were saying, `Well, since when has Star W...    J.J. Abrams
#
#                                                 qids        date  \
# 0                                        [Q16843606]  2015-11-15
# 1                                         [Q7279255]  2015-10-07
# 2  [Q18202175, Q1373440, Q1259234, Q24005690, Q74...  2015-12-10
# 3  [Q1173911, Q18719363, Q5232111, Q16195447, Q19...  2015-10-03
# 4                                          [Q188137]  2015-12-21
#
#    numOccurrences                                             probas  \
# 0               1             [[Laci Green, 0.9013], [None, 0.0987]]
# 1               1  [[Rachel Gordon, 0.7129], [None, 0.2673], [Mar...
# 2               2  [[None, 0.4806], [Scott Davis, 0.4017], [Antho...
# 3               2  [[None, 0.7792], [David Cameron, 0.1805], [Eri...
# 4               1  [[J.J. Abrams, 0.5868], [None, 0.2584], [Lupit...
#
#                                                 urls  \
# 0  [http://www.dailykos.com/story/2015/11/15/1450...
# 1  [http://missionlocal.org/2015/10/sf-gets-more-...
# 2  [http://www.flickeringmyth.com/2015/12/is-dare...
# 3  [http://www.blogtalkradio.com/theafricanhistor...
# 4  [http://rssfeeds.usatoday.com/~/129385923/0/us...
#
#                                         movie  shared_ID
# 0       The Hunger Games: Mockingjay - Part 2       1109
# 1          Mission: Impossible - Rogue Nation       7839
# 2                     Avengers: Age of Ultron       1405
# 3       The Hunger Games: Mockingjay - Part 2        181
# 4  Star Wars: Episode VII - The Force Awakens       1538

# %% [markdown]
# ### Investigating the new ID's

# %% [markdown]
# We will now investigate how different ID's (the shared one) are distributed across quotes. We calculate the frequency with which ID is associated, meaning the total number of occurences for each ID.

# %%
print(f"Number of unique IDs: {np.max(df.shared_ID)}")

# %%
freq_occurences = defaultdict(dict)

for ID in tqdm(newIDs):
    freq_occurences[ID] = sum(df[df['shared_ID'] == ID].numOccurrences)
# Out:
#   0%|          | 0/34699 [00:00<?, ?it/s]

# %%
freq_list = [(ID, count) for ID, count in sorted(freq_occurences.items(), key=lambda item: item[1], reverse=True)]
ID, freq = list(zip(*freq_list))
ID, freq = np.array(ID), np.array(freq)

# %% [markdown]
# Using a boxplot we also see that these ones seem to be full of outliers and by plotting the amount of occurrences with the speakers sorted in a descending manner, we see that the distribution looks like a strong power law.

# %%
plt.boxplot(freq)
plt.ylabel("NumOccurrences")
plt.show()

# %%
plt.plot(np.arange(len(freq)), freq)
plt.xlabel("Ordered speakers (based on shared ID)")
plt.ylabel("NumOccurrences")
plt.show()

# %% [markdown]
# We do not regard this as a problem, since it seems reasonable that this depicts the real-world scenario where some people - like star directors and movie stars - have more to say than actors that are not playing in movies at the current time but still gets quoted once in a while.

# %% [markdown]
# By looking at the shared_ID, we now see that the ambiguity of speakers is now reduced - which will be useful in further analyses - as the new `shared_ID` attribute captures identical speaker denoted by different names.

# %%
N = 25
topN = []

print(f"Most quoted ID's: \n (shared_ID, total numOccurrences, associated speakers)\n")
for n in range(N):
    
    idxs = [i for (i, shared) in enumerate(df.shared_ID) if shared == ID[n]]
    associated_speakers = df.iloc[idxs, :].speaker.unique()
    
    info_tuple = (ID[n], freq[n], list(associated_speakers))
    topN.append(info_tuple)
    
    print(f"{n+1}) {topN[n]}\n")
# Out:
# Most quoted ID's:
#  (shared_ID, total numOccurrences, associated speakers)
#
# 1) (5592, 1343, ['Kevin Feige', 'KEVIN FEIGE'])
#
# 2) (4459, 1062, ['Captain Marvel', 'Michael Jordan'])
#
# 3) (1538, 860, ['J.J. Abrams', 'JJ Abrams', 'J. J. Abrams', 'jj abrams', 'J J Abrams', 'J.J. ABRAMS'])
#
# 4) (1143, 733, ['Joe Russo', 'Joseph Russo', 'joe russo'])
#
# 5) (5929, 590, ['Bob Iger', 'Robert Iger', 'Robert A. Iger', 'BOB IGER'])
#
# 6) (370, 425, ['Tom Holland', 'TOM HOLLAND'])
#
# 7) (2519, 406, ['Kathleen Kennedy'])
#
# 8) (1599, 400, ['Ryan Reynolds'])
#
# 9) (556, 385, ['George Lucas', 'GEORGE LUCAS'])
#
# 10) (995, 358, ['Robert Downey', 'Robert Downey Jr. .'])
#
# 11) (8344, 350, ['Todd Phillips'])
#
# 12) (3440, 349, ['Jon Favreau'])
#
# 13) (5056, 331, ['Anthony Russo'])
#
# 14) (5483, 271, ['Chris Evans'])
#
# 15) (3392, 261, ['Brie Larson', 'brie larson'])
#
# 16) (1162, 253, ['John Boyega'])
#
# 17) (58, 234, ['Narendra Modi', 'narendra modi'])
#
# 18) (8357, 224, ['Tom Hardy'])
#
# 19) (4256, 220, ['James Wan', 'James wan'])
#
# 20) (6725, 220, ['Stephen McFeely'])
#
# 21) (6052, 210, ['Chris Hemsworth', 'chris hemsworth', 'CHRIS HEMSWORTH'])
#
# 22) (2024, 208, ['Mark Hamill'])
#
# 23) (5422, 207, ['Chadwick Boseman'])
#
# 24) (4118, 199, ['Will Smith', 'WILL SMITH', 'WILL Smith', 'Fresh Prince'])
#
# 25) (1455, 192, ['Joaquin Phoenix', 'JOAQUIN PHOENIX'])

# %% [markdown]
# ### Add sentiment of quotes

# %% [markdown]
# We use the `Afinn` sentiment lexicon for mapping a sentiment score to each quote in the preprocessed Quotebank data.

# %%
# !pip install Afinn
from afinn import Afinn
# Out:
# Requirement already satisfied: Afinn in c:\programdata\anaconda3\lib\site-packages (0.1)

# %%
afn = Afinn()
sentiments = [afn.score(quote) for quote in tqdm(df.quotation)]
df['sentiment'] = sentiments
# Out:
#   0%|          | 0/34699 [00:00<?, ?it/s]

# %% [markdown]
# And now we see the average, max, min, etc. of the attribute.

# %%
df.sentiment.describe()
# Out:
# count    34699.000000
# mean         2.266117
# std          5.411369
# min        -45.000000
# 25%          0.000000
# 50%          1.000000
# 75%          4.000000
# max         89.000000
# Name: sentiment, dtype: float64

# %% [markdown]
# The dataframe is saved as a pickle and we investigate the sentiment further in the `sentiment.ipynb` file.

# %%
# Save loaded DataFrame as pickle for faster loading time in the future
df.to_pickle(rf"{data_dir}\Quotebank_wSentiment.pkl")
print(f"Dataframe was pickled and saved to directory:\n" + data_dir)
# Out:
# Dataframe was pickled and saved to directory:
# C:\Users\Albert Kjøller\Documents\EPFL\Courses\CS-401_ADA\ada-2021-project-f-jab\data

# %%
N = len(df)-1
topN = []

print(f"Most quoted ID's: \n (shared_ID, total numOccurrences, associated speakers)\n")
for n in range(N):
    
    idxs = [i for (i, shared) in enumerate(df.shared_ID) if shared == ID[n]]
    associated_speakers = df.iloc[idxs, :].speaker.unique()
    
    info_tuple = (ID[n], freq[n], list(associated_speakers))
    topN.append(info_tuple)
    
    print(f"{n+1}) {topN[n]}\n")
# Out:
# Most quoted ID's:
#  (shared_ID, total numOccurrences, associated speakers)
#
# 1) (5592, 1343, ['Kevin Feige', 'KEVIN FEIGE'])
#
# 2) (4459, 1062, ['Captain Marvel', 'Michael Jordan'])
#
# 3) (1538, 860, ['J.J. Abrams', 'JJ Abrams', 'J. J. Abrams', 'jj abrams', 'J J Abrams', 'J.J. ABRAMS'])
#
# 4) (1143, 733, ['Joe Russo', 'Joseph Russo', 'joe russo'])
#
# 5) (5929, 590, ['Bob Iger', 'Robert Iger', 'Robert A. Iger', 'BOB IGER'])
#
# 6) (370, 425, ['Tom Holland', 'TOM HOLLAND'])
#
# 7) (2519, 406, ['Kathleen Kennedy'])
#
# 8) (1599, 400, ['Ryan Reynolds'])
#
# 9) (556, 385, ['George Lucas', 'GEORGE LUCAS'])
#
# 10) (995, 358, ['Robert Downey', 'Robert Downey Jr. .'])
#
# 11) (8344, 350, ['Todd Phillips'])
#
# 12) (3440, 349, ['Jon Favreau'])
#
# 13) (5056, 331, ['Anthony Russo'])
#
# 14) (5483, 271, ['Chris Evans'])
#
# 15) (3392, 261, ['Brie Larson', 'brie larson'])
#
# 16) (1162, 253, ['John Boyega'])
#
# 17) (58, 234, ['Narendra Modi', 'narendra modi'])
#
# 18) (8357, 224, ['Tom Hardy'])
#
# 19) (4256, 220, ['James Wan', 'James wan'])
#
# 20) (6725, 220, ['Stephen McFeely'])
#
# 21) (6052, 210, ['Chris Hemsworth', 'chris hemsworth', 'CHRIS HEMSWORTH'])
#
# 22) (2024, 208, ['Mark Hamill'])
#
# 23) (5422, 207, ['Chadwick Boseman'])
#
# 24) (4118, 199, ['Will Smith', 'WILL SMITH', 'WILL Smith', 'Fresh Prince'])
#
# 25) (1455, 192, ['Joaquin Phoenix', 'JOAQUIN PHOENIX'])
#
# 26) (6009, 189, ['Erik Davis'])
#
# 27) (1456, 189, ['Jon Watts'])
#
# 28) (4331, 184, ["Lupita Nyong ' o", "Lupita Amondi Nyong ' o"])
#
# 29) (4460, 184, ['Mark Ruffalo'])
#
# 30) (3471, 180, ['Joss Whedon'])
#
# 31) (7223, 176, ['Kevin Smith'])
#
# 32) (4230, 173, ['Tom Cruise', 'tom cruise'])
#
# 33) (8033, 164, ['Ryan Coogler', 'RYAN COOGLER'])
#
# 34) (6996, 163, ['Rian Johnson'])
#
# 35) (5691, 162, ['Ruben Fleischer', 'Ruben fleischer'])
#
# 36) (7764, 161, ['Peter Parker'])
#
# 37) (150, 161, ['James Gunn'])
#
# 38) (3702, 149, ['Jason Momoa', 'JASON MOMOA'])
#
# 39) (5366, 144, ['Chris Pratt', 'chris pratt', 'CHRIS PRATT'])
#
# 40) (5587, 140, ['Colin Trevorrow'])
#
# 41) (8581, 138, ['Peyton Reed'])
#
# 42) (5549, 135, ['Christopher Markus'])
#
# 43) (1071, 134, ['Daisy Ridley', 'DAISY RIDLEY'])
#
# 44) (2864, 132, ['Todd Howard'])
#
# 45) (2230, 123, ['Simon Kinberg', 'SIMON KINBERG'])
#
# 46) (3987, 114, ['Scarlett Johansson'])
#
# 47) (776, 111, ['Stan Lee'])
#
# 48) (3148, 110, ['Donald Trump', 'President Donald Trump', 'President Trump'])
#
# 49) (1224, 106, ['Samuel L. Jackson', 'SAMUEL L. JACKSON', 'Sam Jackson'])
#
# 50) (2445, 104, ['Jeremy Renner'])
#
# 51) (2824, 101, ['Dave Filoni'])
#
# 52) (7072, 99, ['John Williams', 'JOHN WILLIAMS'])
#
# 53) (2141, 97, ['Gareth Edwards'])
#
# 54) (2096, 97, ['Stephen Colbert', 'STEPHEN COLBERT'])
#
# 55) (5218, 96, ['Jimmy Kimmel', 'JIMMY Kimmel', 'JIMMY KIMMEL'])
#
# 56) (3950, 96, ['Christopher McQuarrie'])
#
# 57) (3433, 95, ['Tom Hiddleston'])
#
# 58) (4060, 95, ['Todd McFarlane', 'TODD McFARLANE'])
#
# 59) (4458, 92, ['Josh Brolin'])
#
# 60) (695, 91, ['Evangeline Lilly'])
#
# 61) (4075, 90, ['Tom Brevoort'])
#
# 62) (8502, 89, ['Peter Travers'])
#
# 63) (8416, 87, ['War Machine'])
#
# 64) (71, 87, ['Dwayne Johnson'])
#
# 65) (2556, 86, ['Simon Pegg'])
#
# 66) (1866, 86, ['Rob Liefeld'])
#
# 67) (8188, 85, ['President Obama', 'President Barack Obama', 'Barack Obama', 'president Obama', 'president Barack Obama'])
#
# 68) (6281, 85, ['Peter Bradshaw'])
#
# 69) (3856, 85, ['Mena Massoud'])
#
# 70) (3344, 84, ['Todd McCarthy'])
#
# 71) (4677, 83, ['Dave Bautista'])
#
# 72) (6433, 82, ['James Cameron'])
#
# 73) (91, 81, ['Carrie Fisher'])
#
# 74) (8462, 81, ['Harrison Ford'])
#
# 75) (2567, 80, ['Taika Waititi'])
#
# 76) (6832, 78, ['James Bond'])
#
# 77) (2619, 78, ['Lawrence Kasdan'])
#
# 78) (7759, 78, ['Peter Mayhew'])
#
# 79) (7800, 77, ['Brian Michael Bendis'])
#
# 80) (5113, 76, ['Jared Leto'])
#
# 81) (869, 75, ['Nate Moore'])
#
# 82) (1200, 74, ['Harry Potter'])
#
# 83) (1916, 73, ['Tim Miller'])
#
# 84) (5560, 72, ['Anthony Mackie'])
#
# 85) (4031, 72, ['Steve Rogers'])
#
# 86) (3865, 71, ['Anna Boden and Ryan Fleck'])
#
# 87) (4714, 70, ['Greg Foster'])
#
# 88) (5267, 70, ['Brandon Davis'])
#
# 89) (1563, 69, ['Jennifer Lawrence', 'jennifer lawrence'])
#
# 90) (2463, 69, ['Elizabeth Olsen'])
#
# 91) (3067, 68, ['Paul Rudd', 'PAUL RUDD'])
#
# 92) (1596, 68, ['Margot Robbie'])
#
# 93) (461, 67, ['Zack Snyder'])
#
# 94) (458, 67, ['Zachary Levi', 'ZACHARY LEVI'])
#
# 95) (4679, 66, ['Anthony Daniels', 'ANTHONY DANIELS'])
#
# 96) (5757, 65, ['David Edelstein'])
#
# 97) (3425, 65, ['Henry Cavill'])
#
# 98) (3052, 65, ['Letitia Wright'])
#
# 99) (4266, 64, ['Venkaiah Naidu'])
#
# 100) (3988, 64, ['Gwyneth Paltrow'])
#
# 101) (7890, 64, ['Rhett Reese'])
#
# 102) (3934, 63, ['Oscar Isaac'])
#
# 103) (5997, 63, ['Eric Greitens'])
#
# 104) (8498, 61, ['Steven Spielberg', 'STEVEN SPIELBERG'])
#
# 105) (4852, 61, ['Adam Driver'])
#
# 106) (3854, 61, ['Michael B. Jordan'])
#
# 107) (7659, 60, ['Owen Gleiberman'])
#
# 108) (3012, 60, ['Tessa Thompson'])
#
# 109) (4822, 59, ['Mamata Banerjee'])
#
# 110) (4267, 59, ['Quentin Tarantino'])
#
# 111) (3522, 59, ['Mike Ryan'])
#
# 112) (351, 58, ['Jason Aaron'])
#
# 113) (4764, 58, ['Sebastian Stan'])
#
# 114) (8310, 57, ['Patrick Bach'])
#
# 115) (3777, 57, ['Kevin Hart'])
#
# 116) (2404, 57, ['Karen Gillan'])
#
# 117) (4950, 55, ['Alonso Duralde'])
#
# 118) (5085, 55, ['Ashley Eckstein'])
#
# 119) (2446, 55, ['Akshay Kumar'])
#
# 120) (3648, 54, ['Brad Bird'])
#
# 121) (2659, 52, ['Paul Bettany'])
#
# 122) (4673, 52, ['Manohla Dargis'])
#
# 123) (2673, 51, ['Brian Truitt'])
#
# 124) (4730, 50, ['Pope Francis'])
#
# 125) (3610, 50, ['Justin Chang'])
#
# 126) (4753, 49, ['Daniel Craig', 'DANIEL CRAIG'])
#
# 127) (2305, 49, ['Sam Mendes'])
#
# 128) (93, 49, ['David Ayer'])
#
# 129) (3182, 48, ['Trinh Tran'])
#
# 130) (7720, 47, ['Paul Wernick'])
#
# 131) (5094, 47, ['Amy Pascal'])
#
# 132) (5371, 47, ['David Benioff'])
#
# 133) (7912, 46, ['Richard Lawson'])
#
# 134) (2374, 46, ['Bryce Dallas Howard'])
#
# 135) (5033, 46, ['Andy Park'])
#
# 136) (208, 46, ['Vlad the Impaler'])
#
# 137) (4264, 46, ['Shaun Escayg'])
#
# 138) (4665, 45, ['Gwendoline Christie'])
#
# 139) (2386, 45, ['Amy Poehler'])
#
# 140) (6527, 45, ['Pranab Mukherjee'])
#
# 141) (5613, 45, ['Ann Hornaday'])
#
# 142) (3249, 45, ['Amy Hennig'])
#
# 143) (3060, 45, ['Sam Raimi'])
#
# 144) (601, 45, ['Ta-Nehisi Coates'])
#
# 145) (4540, 45, ['Chris McKenna'])
#
# 146) (3789, 45, ['Chris Terrio'])
#
# 147) (3925, 44, ['Jimmy Fallon'])
#
# 148) (503, 44, ['Stephanie Zacharek'])
#
# 149) (362, 44, ['Jake Gyllenhaal'])
#
# 150) (7279, 44, ['Laura Barton'])
#
# 151) (7137, 44, ['Danai Gurira'])
#
# 152) (3641, 43, ['Damon Lindelof'])
#
# 153) (3631, 42, ['Justin Trudeau'])
#
# 154) (2616, 42, ['Peter Sciretta'])
#
# 155) (2685, 42, ['Benedict Cumberbatch'])
#
# 156) (5084, 41, ['Doug Chiang'])
#
# 157) (271, 41, ['Donald Glover'])
#
# 158) (7404, 40, ['Mark Millar'])
#
# 159) (5026, 40, ['Andrew Wilson'])
#
# 160) (8387, 40, ['Trevor Noah'])
#
# 161) (227, 40, ['Naveen Patnaik'])
#
# 162) (7081, 40, ['Jon Schnepp'])
#
# 163) (4407, 39, ['Steve Sansweet'])
#
# 164) (121, 39, ['Clark Gregg'])
#
# 165) (1478, 39, ['Riz Ahmed'])
#
# 166) (4671, 39, ['Werner Herzog', 'werner herzog'])
#
# 167) (3176, 38, ['Ryan Meinerding'])
#
# 168) (696, 38, ['Jude Law'])
#
# 169) (2387, 38, ['Josh Hawley'])
#
# 170) (274, 37, ['Chance the Rapper', 'Chance The Rapper'])
#
# 171) (2157, 37, ['Chuck Wendig'])
#
# 172) (5804, 37, ['David Sims'])
#
# 173) (2084, 37, ['Roger Ebert'])
#
# 174) (606, 37, ['Steve Weintraub', 'Steven Weintraub'])
#
# 175) (2353, 37, ['Amber Heard'])
#
# 176) (3018, 37, ['Don Cheadle'])
#
# 177) (3288, 36, ['Brian Lowry'])
#
# 178) (6283, 36, ['Ridley Scott'])
#
# 179) (3674, 36, ['John Krasinski', 'JOHN KRASINSKI'])
#
# 180) (7450, 36, ['Matt Singer'])
#
# 181) (7624, 36, ['Nick Spencer'])
#
# 182) (4033, 35, ['Stephane Dujarric', 'Stéphane Dujarric'])
#
# 183) (3109, 35, ['Angie Han'])
#
# 184) (5079, 35, ['Arthur Morgan'])
#
# 185) (7772, 35, ['Peter Safran'])
#
# 186) (506, 35, ['Pedro Pascal'])
#
# 187) (4161, 34, ['Arun Jaitley'])
#
# 188) (7254, 34, ['David Denman'])
#
# 189) (4297, 34, ['Richard E. Grant'])
#
# 190) (1193, 34, ['LeBron James', 'King James', 'Lebron James'])
#
# 191) (652, 34, ['Matt Aitken'])
#
# 192) (4016, 34, ['John Carpenter', 'JOHN CARPENTER'])
#
# 193) (5035, 33, ['Andy Weir'])
#
# 194) (8562, 33, ['Drew Struzan'])
#
# 195) (5292, 33, ['Brian Cronin'])
#
# 196) (3538, 33, ['Dan Slott'])
#
# 197) (673, 32, ['Kanye West'])
#
# 198) (1511, 32, ['Imran Khan'])
#
# 199) (2977, 32, ['Winston Duke'])
#
# 200) (6379, 31, ['David Campos'])
#
# 201) (7512, 31, ['Michael Phillips'])
#
# 202) (5189, 31, ['Amitabh Bachchan', 'Big B', 'amitabh bachchan'])
#
# 203) (426, 31, ['Geoff Johns'])
#
# 204) (424, 31, ['Jeph Loeb'])
#
# 205) (3505, 31, ['Jim Lee'])
# 206) (3224, 31, ['EDDIE REDMAYNE', 'Eddie Redmayne'])
#
# 207) (1001, 30, ['Ewan McGregor', 'EWAN McGREGOR', 'EWAN McGregor'])
#
# 208) (2984, 30, ['Eric Eisenberg'])
#
# 209) (4651, 30, ['Patrick Brown', 'Patrick O. Brown'])
#
# 210) (996, 30, ['Sushma Swaraj'])
#
# 211) (7952, 30, ['Robbie Collin'])
#
# 212) (2998, 30, ['Germain Lussier'])
#
# 213) (1401, 30, ['Dolph Lundgren'])
#
# 214) (4396, 30, ['Ruth E. Carter'])
#
# 215) (6738, 30, ['Scott Snyder', 'SCOTT SNYDER'])
#
# 216) (941, 30, ['Shameik Moore'])
#
# 217) (534, 29, ['Tim Lucas'])
#
# 218) (5250, 29, ['Rebecca Ferguson'])
#
# 219) (7682, 29, ['Pat McGrath'])
#
# 220) (2886, 29, ['Jeremy Latcham'])
#
# 221) (3838, 29, ['Mark Hughes'])
#
# 222) (2061, 29, ['Pablo Hidalgo'])
#
# 223) (6063, 29, ['Avi Arad'])
#
# 224) (1820, 29, ['Nick Jonas'])
#
# 225) (2255, 29, ['Bryan Singer', 'BRYAN SINGER'])
#
# 226) (8507, 29, ['Henry Wu'])
#
# 227) (4556, 29, ['Matt Tolmach'])
#
# 228) (332, 29, ['Kendrick Lamar'])
#
# 229) (2415, 29, ['Angela Bassett'])
#
# 230) (8467, 28, ['Ben Mendelsohn'])
#
# 231) (4105, 28, ['Gary Glitter'])
#
# 232) (4450, 28, ['Martin Scorsese'])
#
# 233) (3546, 27, ['David Gabriel'])
#
# 234) (2625, 27, ['Edwin M. Lee', 'Ed Lee'])
#
# 235) (6170, 27, ['Gary Whitta'])
#
# 236) (1310, 27, ['Matt Damon'])
#
# 237) (4128, 27, ['Billy Dee Williams'])
#
# 238) (7184, 27, ['Kelly Sue DeConnick'])
#
# 239) (1613, 27, ['Guy Ritchie'])
#
# 240) (1631, 27, ['James McAvoy'])
#
# 241) (8144, 27, ['Shannon Bream'])
#
# 242) (2137, 27, ['Tim Allen'])
#
# 243) (5656, 27, ['Chris Avellone'])
#
# 244) (408, 27, ['Ludwig Göransson'])
#
# 245) (2332, 27, ['Hiram Garcia'])
#
# 246) (1825, 26, ['Richard Roeper'])
#
# 247) (2228, 26, ['Elizabeth Banks'])
#
# 248) (2359, 26, ['Jessica Chastain'])
#
# 249) (2483, 26, ['Kenneth Turan'])
#
# 250) (8307, 26, ['Tom Rothman'])
#
# 251) (500, 26, ['Harsh Vardhan'])
#
# 252) (1566, 26, ['Wesley Snipes'])
#
# 253) (4716, 26, ['John Stephens'])
#
# 254) (7445, 26, ['Matt Martin'])
#
# 255) (2652, 26, ['Ethan Sacks'])
#
# 256) (2109, 26, ['Jonathan Schwartz'])
#
# 257) (1405, 25, ['Scott Davis'])
#
# 258) (6731, 25, ['Mark Waid'])
#
# 259) (5095, 25, ['Brian Goldner'])
#
# 260) (217, 25, ['Mick LaSalle'])
#
# 261) (328, 25, ['Jason Ward'])
#
# 262) (5099, 25, ['Ava DuVernay', 'Ava Duvernay'])
#
# 263) (4259, 25, ['Rami Malek'])
#
# 264) (6378, 25, ['Hardeep Singh Puri'])
#
# 265) (3339, 25, ['Hillary Ronen'])
#
# 266) (405, 25, ['Kami Garcia'])
#
# 267) (5872, 25, ['Henry Abrams'])
#
# 268) (5451, 24, ['Charlie Cox'])
#
# 269) (6025, 24, ['Mindy Kaling'])
#
# 270) (8265, 24, ['James Corden'])
#
# 271) (2941, 24, ['Taylor Swift'])
#
# 272) (5216, 24, ['Billy Eichner'])
#
# 273) (7510, 23, ['Michael Pachter'])
#
# 274) (2622, 23, ['Matt Goldberg'])
#
# 275) (5523, 23, ['Chris Taylor'])
#
# 276) (5106, 23, ['Ellen DeGeneres'])
#
# 277) (2751, 23, ['Lou Ferrigno'])
#
# 278) (962, 23, ['Blake Lively'])
#
# 279) (430, 23, ['Jim Starlin', 'JIM STARLIN'])
#
# 280) (373, 23, ['Bill Burr'])
#
# 281) (1116, 23, ['Jeff Lemire'])
#
# 282) (4578, 23, ['Sean Gunn'])
#
# 283) (2447, 23, ['Stefan Weckbach'])
#
# 284) (4726, 23, ['David Harbour'])
#
# 285) (3676, 23, ['Jon Hamm', 'JON HAMM'])
#
# 286) (5596, 23, ['Spike Lee', 'Mars Blackmon'])
#
# 287) (3832, 23, ['Marc Maron'])
#
# 288) (84, 22, ['Warwick Davis'])
#
# 289) (3617, 22, ['al Sisi', 'Abdel Fattah el-Sisi', 'Abdel Fattah al-Sisi'])
#
# 290) (8395, 22, ['Varun Dhawan'])
#
# 291) (67, 22, ['Jeff Goldblum'])
#
# 292) (6271, 22, ['Charles Soule'])
#
# 293) (1746, 22, ['Ron Howard'])
#
# 294) (3942, 22, ['Jordan Peele'])
#
# 295) (6838, 22, ['Uwe Boll'])
#
# 296) (8185, 22, ['Stan the Man'])
#
# 297) (5603, 22, ['Patrick Wilson'])
#
# 298) (4429, 22, ['Heath Ledger'])
#
# 299) (322, 22, ['Toby Emmerich'])
#
# 300) (3317, 22, ['Barry Jenkins'])
#
# 301) (8572, 22, ['Cameron Monaghan'])
#
# 302) (6318, 21, ['Francis Lawrence'])
#
# 303) (2471, 21, ['Hayley Atwell'])
#
# 304) (928, 21, ['Felicity Jones', 'FELICITY Jones'])
#
# 305) (4146, 21, ['Irrfan Khan'])
#
# 306) (2216, 21, ['Katherine Timpf'])
#
# 307) (3105, 21, ['Gordy Haab'])
#
# 308) (2039, 21, ['Rob Williams'])
#
# 309) (6448, 21, ['D. White'])
#
# 310) (1406, 21, ['Adam Aron'])
#
# 311) (1555, 21, ['David Yates'])
#
# 312) (5395, 21, ['Catherine Hanaway'])
#
# 313) (2811, 21, ['Naomi Scott'])
#
# 314) (4039, 20, ['Adam Rogers'])
#
# 315) (4303, 20, ['Jonathan Hickman'])
#
# 316) (4768, 20, ['Domhnall Gleeson'])
#
# 317) (340, 20, ['Rochas Okorocha'])
#
# 318) (4590, 20, ['Matthew Smith', 'Matt Smith'])
#
# 319) (7112, 20, ['Hillary Clinton', 'HILLARY CLINTON'])
#
# 320) (7204, 20, ['Kevin Faulconer'])
#
# 321) (5102, 20, ['Ben Affleck'])
#
# 322) (4176, 20, ['Richard Gelfond'])
#
# 323) (7521, 20, ['Mick Ebeling'])
#
# 324) (323, 20, ['Hugh Jackman'])
#
# 325) (388, 20, ['Ghost Rider'])
#
# 326) (580, 20, ['Cullen Bunn'])
#
# 327) (2705, 20, ['Jen Yamato'])
#
# 328) (4446, 20, ['Wade Wilson'])
#
# 329) (1828, 20, ['Oliver Blume'])
#
# 330) (3157, 20, ['Darren Franich'])
#
# 331) (2626, 20, ['Victoria Alonso'])
#
# 332) (3969, 20, ['Rana Daggubati'])
#
# 333) (6440, 20, ['Heather Nauert'])
#
# 334) (4257, 20, ['Nicole Kidman'])
#
# 335) (7989, 20, ['Rodney Rothman'])
#
# 336) (2978, 20, ['Aaron Contreras'])
#
# 337) (4439, 19, ['Sandra Bullock'])
#
# 338) (3985, 19, ['Roger Moore'])
#
# 339) (2893, 19, ['Joe Quesada'])
#
# 340) (1545, 19, ['Thom Yorke'])
#
# 341) (2214, 19, ['Will Ferrell'])
#
# 342) (6480, 19, ['Luke Owen'])
#
# 343) (4784, 19, ['Christian Bale'])
#
# 344) (8534, 19, ['FRANK GRILLO', 'Frank Grillo'])
#
# 345) (5512, 19, ['Christopher Priest'])
#
# 346) (4097, 19, ['Raveesh Kumar'])
#
# 347) (5469, 19, ['Céline Dion'])
#
# 348) (1572, 19, ['Zoe Saldana'])
#
# 349) (2361, 19, ['Keri Russell'])
#
# 350) (6454, 19, ['Dan Lin'])
#
# 351) (4311, 18, ['Vikas Swarup'])
#
# 352) (1624, 18, ['Noel Gallagher'])
#
# 353) (7386, 18, ['Mark Clark'])
#
# 354) (3646, 18, ['Neil deGrasse Tyson'])
#
# 355) (8321, 18, ['Tim League'])
#
# 356) (4087, 18, ['Ty Burr'])
#
# 357) (4416, 18, ['Ahmed Best'])
#
# 358) (5704, 18, ['Danny Bowien'])
#
# 359) (619, 18, ['Michael Giacchino'])
#
# 360) (5190, 18, ['Bilge Ebiri'])
#
# 361) (5057, 18, ['Anthony Stark'])
#
# 362) (1296, 18, ['Billie Lourd'])
#
# 363) (3560, 18, ['Mike Myers'])
#
# 364) (1724, 18, ['David Lee'])
#
# 365) (3895, 18, ['Benedict Wong'])
#
# 366) (3277, 18, ['Yahya Abdul-Mateen II'])
#
# 367) (6252, 18, ['Marc Bernardin'])
#
# 368) (8515, 17, ['Ranveer Singh'])
#
# 369) (1060, 17, ['Noura Al Kaabi'])
#
# 370) (4252, 17, ['Patton Oswalt'])
#
# 371) (6256, 17, ['Piers Morgan'])
#
# 372) (6567, 17, ['Jens Stoltenberg'])
#
# 373) (5626, 17, ['Tim Peake'])
#
# 374) (3043, 17, ['Charles Roven'])
#
# 375) (492, 17, ['Seth Meyers', 'SETH MEYERS'])
#
# 376) (4284, 17, ['Natalie Portman'])
#
# 377) (4307, 17, ['Leonardo DiCaprio'])
#
# 378) (3627, 17, ['Martin Freeman'])
#
# 379) (4020, 17, ['Alan Tudyk'])
#
# 380) (103, 17, ['Ken Burns'])
#
# 381) (2542, 17, ['Joe Robert Cole'])
#
# 382) (3683, 17, ['Alan Silvestri'])
#
# 383) (4037, 17, ['Rajnath Singh'])
#
# 384) (7793, 17, ['Nana Addo Dankwa Akufo-Addo'])
#
# 385) (3839, 17, ['Sterling K. Brown'])
#
# 386) (4354, 17, ['Nnedi Okorafor'])
#
# 387) (6437, 16, ['Heather Humphreys'])
#
# 388) (6931, 16, ['Tom Stone'])
#
# 389) (6665, 16, ['Liam Neeson'])
#
# 390) (1203, 16, ['Jon Stewart', 'jon stewart'])
#
# 391) (632, 16, ['Naomie Harris'])
#
# 392) (3084, 16, ['Sam Smith', 'sam smith'])
#
# 393) (1951, 16, ['Peter Moore'])
#
# 394) (6104, 16, ['Frank Marshall'])
#
# 395) (1999, 16, ['Chandrasekhar Rao'])
#
# 396) (3658, 16, ['Robert Kirkman'])
#
# 397) (3657, 16, ['Donnie Yen'])
#
# 398) (5963, 16, ['John Blackburn'])
#
# 399) (8411, 16, ['Volume 10'])
#
# 400) (3161, 16, ['Brian Roberts', 'Brian L. Roberts'])
#
# 401) (4036, 16, ['Nitin Gadkari'])
#
# 402) (7350, 16, ['Rohit Shetty'])
#
# 403) (3472, 16, ['Rob Zombie'])
#
# 404) (5502, 16, ['Chris Lee'])
#
# 405) (2802, 16, ['Ming-Na Wen'])
#
# 406) (8125, 16, ['Jenny Slate'])
#
# 407) (2993, 16, ['Cheo Hodari Coker'])
#
# 408) (7568, 16, ['Milton Johnson'])
#
# 409) (1089, 16, ['David F. Sandberg', 'David F Sandberg'])
#
# 410) (6504, 16, ['Paul Franklin'])
#
# 411) (3154, 16, ['Laura Prudom'])
#
# 412) (2665, 16, ['Lashana Lynch'])
#
# 413) (2571, 16, ['Michelle Williams'])
#
# 414) (4870, 16, ['Karan Johar'])
#
# 415) (3199, 16, ['Elton John'])
#
# 416) (2065, 16, ['Aryan Khan'])
#
# 417) (490, 16, ['Ted Price'])
#
# 418) (4983, 15, ['Sam Singer'])
#
# 419) (2087, 15, ['Diane Robertson'])
#
# 420) (4123, 15, ['Pete Docter'])
#
# 421) (2849, 15, ['Matthew Vaughn'])
#
# 422) (3186, 15, ['Kiri Hart'])
#
# 423) (7228, 15, ['Kieron Gillen'])
#
# 424) (4982, 15, ['Amy Schumer'])
#
# 425) (6625, 15, ['Nicolas Maduro', 'Nicolás Maduro'])
#
# 426) (3816, 15, ['Jeff Pinkner'])
# 427) (3729, 15, ['Jed Whedon'])
#
# 428) (7439, 15, ['Matt Busch'])
#
# 429) (4046, 15, ['Chandrababu Naidu', 'N. Chandrababu Naidu'])
#
# 430) (3703, 15, ['Ian McDiarmid'])
#
# 431) (1876, 15, ['Chris Heatherly'])
#
# 432) (4489, 15, ['Denzel Washington'])
#
# 433) (3571, 15, ['Jack Posobiec'])
#
# 434) (3754, 15, ['John Wick'])
#
# 435) (4133, 15, ['Bernie Sanders'])
#
# 436) (4973, 15, ['Amit Shah'])
#
# 437) (4592, 15, ['Darnell Hunt'])
#
# 438) (6264, 15, ['Scott Derrickson'])
#
# 439) (5301, 15, ['Brian Kemp'])
#
# 440) (483, 15, ['Franco Mulakkal'])
#
# 441) (913, 15, ['Colin Stevens'])
#
# 442) (6489, 15, ['L Jackson'])
#
# 443) (8558, 15, ['Matt Reeves'])
#
# 444) (4878, 15, ['Lauren Shuler Donner'])
#
# 445) (3785, 15, ['Carl Weathers'])
#
# 446) (1341, 14, ['Vin Diesel'])
#
# 447) (8160, 14, ['Siddharth Roy Kapur'])
#
# 448) (3042, 14, ['Maneka Gandhi'])
#
# 449) (1208, 14, ['Shawn Layden'])
#
# 450) (2513, 14, ['Natalie Dormer'])
#
# 451) (1838, 14, ['Ron Dunn'])
#
# 452) (8617, 14, ['Nick Lowe'])
#
# 453) (4975, 14, ['Amod Mehra'])
#
# 454) (8576, 14, ['Grant Morrison'])
#
# 455) (5322, 14, ['Bruce Nash'])
#
# 456) (7475, 14, ['Melanie Smith'])
#
# 457) (6750, 14, ['Harish Rao'])
#
# 458) (7082, 14, ['Jonas Rivera'])
#
# 459) (1161, 14, ['Joonas Suotamo'])
#
# 460) (3010, 14, ['Tom King'])
#
# 461) (8016, 14, ['Roy Thomas'])
#
# 462) (3726, 14, ['Elon Musk'])
#
# 463) (819, 14, ['Tiger Shroff'])
#
# 464) (147, 14, ['T.J. Miller'])
#
# 465) (2503, 14, ['Olivia Munn'])
#
# 466) (6780, 14, ['Jai Courtney'])
#
# 467) (7803, 14, ['Dan Abnett'])
#
# 468) (143, 14, ['Hideo Kojima'])
#
# 469) (7977, 14, ['Sophie Turner'])
#
# 470) (1899, 14, ['Matt Miller', 'Matthew Miller'])
#
# 471) (5111, 14, ['Jack Black'])
#
# 472) (2885, 14, ['Erik Sommers'])
#
# 473) (8042, 14, ['Ryder Windham'])
#
# 474) (1668, 14, ['Jake Cannavale'])
#
# 475) (5800, 14, ['David Rooney'])
#
# 476) (7896, 13, ['Richard Barry'])
#
# 477) (4243, 13, ['ERNEST CLINE', 'Ernest Cline'])
#
# 478) (8306, 13, ['Tom Staggs'])
#
# 479) (4015, 13, ['Howard Stern'])
#
# 480) (4634, 13, ['Patrick Macnee'])
#
# 481) (1117, 13, ['Jeff Tweedy'])
#
# 482) (2555, 13, ['George Clooney'])
#
# 483) (2475, 13, ['George W. Bush', 'Bush Jr. .', 'President Bush', 'President George W. Bush', 'President George H.W. Bush'])
#
# 484) (375, 13, ['Queen of Hearts'])
#
# 485) (310, 13, ['David Prowse'])
#
# 486) (2570, 13, ['Andrew Garfield'])
#
# 487) (6275, 13, ['Ajay Bijli', 'AJAY Bijli'])
#
# 488) (2872, 13, ['Bill Nye', 'Bill Nye the Science Guy', 'BILL NYE'])
#
# 489) (144, 13, ['Nolan North'])
#
# 490) (1909, 13, ['Andy Serkis'])
#
# 491) (283, 13, ['Ban Ki-moon', 'Ban Ki Moon'])
#
# 492) (7745, 13, ['Peter David'])
#
# 493) (2950, 13, ['John Lasseter'])
#
# 494) (5332, 13, ['Bryan Bishop'])
#
# 495) (8248, 13, ['Hans Zimmer'])
#
# 496) (1348, 13, ['marc guggenheim', 'Marc Guggenheim'])
#
# 497) (1464, 13, ['Gal Gadot'])
#
# 498) (1548, 13, ['Matthew McConaughey'])
#
# 499) (3413, 13, ['Mads Mikkelsen'])
#
# 500) (8002, 13, ['Ron Johnson'])
#
# 501) (6769, 13, ['Gary Ross'])
#
# 502) (7162, 13, ['Katie Walsh'])
#
# 503) (3951, 13, ['Phil Lord'])
#
# 504) (5219, 13, ['Bipin Rawat'])
#
# 505) (2799, 13, ['Lisa Ingram'])
#
# 506) (5978, 13, ['Emil Pagliarulo'])
#
# 507) (2633, 13, ['Julian Dennison'])
#
# 508) (179, 13, ['David Braben'])
#
# 509) (3653, 13, ['Antonio Guterres', 'António Guterres'])
#
# 510) (4744, 13, ['Yara Shahidi'])
#
# 511) (6601, 13, ['Kelly Thompson'])
#
# 512) (4357, 13, ['Ruth Carter'])
#
# 513) (5429, 13, ['Charles Barkley'])
#
# 514) (7768, 13, ['Peter Quill'])
#
# 515) (949, 13, ['Emma Fuhrmann'])
#
# 516) (3779, 13, ['Kevin Shinick'])
#
# 517) (3563, 13, ['Kelly Marie Tran'])
#
# 518) (1847, 13, ['Robin Roberts'])
#
# 519) (5648, 13, ['Cathy Yan'])
#
# 520) (7291, 13, ['Lawrence Sher'])
#
# 521) (6717, 13, ['Megan Thee Stallion'])
#
# 522) (3823, 12, ['Veronica Roth'])
#
# 523) (5442, 12, ['Jason Fry'])
#
# 524) (3207, 12, ['Sir John'])
#
# 525) (4053, 12, ['Mohan Bhagwat'])
#
# 526) (4155, 12, ['Scott Kelly'])
#
# 527) (3911, 12, ['Nina Jacobson'])
#
# 528) (6464, 12, ["Helen O'hara", "Helen O'Hara"])
#
# 529) (6961, 12, ['Patrick Söderlund'])
#
# 530) (3137, 12, ['Salman Khan'])
#
# 531) (7059, 12, ['John Simon'])
#
# 532) (3722, 12, ['Chiwetel Ejiofor'])
#
# 533) (1650, 12, ['Sana Amanat'])
#
# 534) (3647, 12, ['Uma Bharti'])
#
# 535) (7466, 12, ['Matthew Rogers'])
#
# 536) (6670, 12, ['Vijay Singh'])
#
# 537) (1801, 12, ['Cobie Smulders'])
#
# 538) (7525, 12, ['Michael Adams', 'Mike Adams'])
#
# 539) (7224, 12, ['Kevin Tsujihara'])
#
# 540) (2283, 12, ['William Bibbiani'])
#
# 541) (2318, 12, ['Christopher Nolan'])
#
# 542) (8461, 12, ['Cate Blanchett'])
#
# 543) (548, 12, ['JK Simmons', 'J.K. Simmons'])
#
# 544) (7830, 12, ['Shane Black'])
#
# 545) (2664, 12, ['Jeff Sneider'])
#
# 546) (8366, 12, ['Tom Taylor'])
#
# 547) (4471, 12, ['David Mazouz'])
#
# 548) (427, 12, ['Jeff Bewkes', 'Jeffrey Bewkes'])
#
# 549) (981, 12, ['Ignatiy Vishnevetsky'])
#
# 550) (847, 12, ['Russell Earl'])
#
# 551) (164, 12, ['Nikki Haley'])
#
# 552) (142, 12, ['Serena Williams'])
#
# 553) (367, 12, ['Emory Douglas'])
#
# 554) (820, 12, ['Roxane Gay'])
#
# 555) (4325, 12, ['Alimorad Farshchian'])
#
# 556) (2967, 12, ['Zazie Beetz', 'ZAZIE BEETZ'])
#
# 557) (6730, 12, ['Glen Weldon'])
#
# 558) (1857, 12, ['Alan Moore'])
#
# 559) (5071, 12, ['Armaan Malik'])
#
# 560) (4549, 12, ['Bobby Cannavale'])
#
# 561) (2683, 12, ['Nicki Ledermann'])
#
# 562) (1799, 12, ['Justin Ridge'])
#
# 563) (1683, 12, ['Lisa Davies'])
#
# 564) (5205, 11, ['Bill Shorten'])
#
# 565) (6556, 11, ['Michael Schenker', 'MICHAEL SCHENKER'])
#
# 566) (7039, 11, ['Simon Williams'])
#
# 567) (2326, 11, ['Tom Hanks'])
#
# 568) (916, 11, ['Matt Zoller Seitz'])
#
# 569) (4028, 11, ['Steve Barnard'])
#
# 570) (316, 11, ['John Campbell', 'John F. Campbell'])
#
# 571) (2924, 11, ['Max Landis'])
#
# 572) (1602, 11, ['Hayden Christensen'])
#
# 573) (8451, 11, ['Julianne Moore'])
#
# 574) (3086, 11, ['Inderpreet Wadhwa'])
#
# 575) (2971, 11, ['Joshua Williamson'])
#
# 576) (8463, 11, ['Pierce Brosnan', 'PIERCE BROSNAN'])
#
# 577) (2105, 11, ['Anthony Lane'])
#
# 578) (3801, 11, ['Marco Rubio'])
#
# 579) (1216, 11, ['Michael Douglas'])
#
# 580) (2496, 11, ['Jade Raymond'])
#
# 581) (3008, 11, ['Tracy Morgan'])
#
# 582) (6429, 11, ['Chris Klimek'])
#
# 583) (6703, 11, ['Arvind Kejriwal'])
#
# 584) (8476, 11, ['Weird Al', "`` Weird Al '' Yankovic"])
#
# 585) (7903, 11, ['Richard Dickson'])
#
# 586) (6284, 11, ['Tim Burton'])
#
# 587) (1659, 11, ['Amandla Stenberg'])
#
# 588) (1646, 11, ['Richard Brody'])
#
# 589) (1366, 11, ['Boris Johnson'])
#
# 590) (5856, 11, ['Alfre Woodard'])
#
# 591) (2444, 11, ['Hrithik Roshan'])
#
# 592) (4824, 11, ['Antoine Fuqua'])
#
# 593) (3090, 11, ['Topher Grace'])
#
# 594) (5194, 11, ['Bill Evans'])
#
# 595) (3645, 11, ['Sanjay Dutt'])
#
# 596) (8602, 11, ['King Khan'])
#
# 597) (1957, 11, ['Anderson . Paak'])
#
# 598) (7106, 11, ['Josh Spiegel'])
#
# 599) (7625, 11, ['Nick Stone'])
#
# 600) (1546, 11, ['Willem Dafoe'])
#
# 601) (4853, 11, ['Adam F. Goldberg'])
#
# 602) (6373, 11, ['Bill Maher'])
#
# 603) (967, 11, ['Dan Silver'])
#
# 604) (1553, 11, ['Cameron Bailey'])
#
# 605) (3994, 11, ['Ryan Fleck'])
#
# 606) (3628, 10, ['Greg Grunberg'])
#
# 607) (5595, 10, ['John Landis'])
#
# 608) (7330, 10, ['Lorie Zapf'])
#
# 609) (7032, 10, ['John Hsu'])
#
# 610) (2480, 10, ['Joe Morgenstern'])
#
# 611) (4038, 10, ['Jim Green'])
#
# 612) (7947, 10, ['Rob Moore'])
#
# 613) (1567, 10, ['Rebecca Keegan'])
#
# 614) (2701, 10, ['Bryan Young'])
#
# 615) (6171, 10, ['Duncan Jones'])
#
# 616) (4330, 10, ['Dave Franco'])
#
# 617) (1677, 10, ['Ted Sarandos'])
#
# 618) (6894, 10, ['Jeff Hickman'])
#
# 619) (4263, 10, ['Gary Barber'])
#
# 620) (1480, 10, ['Kim Kardashian'])
#
# 621) (6643, 10, ['Adam Savage'])
#
# 622) (3922, 10, ['Sam Hawgood'])
#
# 623) (3750, 10, ['Floyd Mayweather Jr. .'])
#
# 624) (2848, 10, ['Willow Shields'])
#
# 625) (872, 10, ['Tenniel Chu'])
#
# 626) (4164, 10, ['Ravi Shankar Prasad'])
#
# 627) (4420, 10, ['Michael Moore'])
#
# 628) (1082, 10, ['James Comey', 'James B. Comey'])
#
# 629) (1645, 10, ['Alex Ross'])
#
# 630) (1855, 10, ['Bradley Cooper'])
#
# 631) (2590, 10, ['Jitendra Singh'])
#
# 632) (7537, 10, ['Mike Fleming'])
#
# 633) (454, 10, ['Cara Delevingne'])
#
# 634) (5871, 10, ['Peter Jackson'])
#
# 635) (6805, 10, ['Roberto Hernandez', 'Roberto Hernández'])
#
# 636) (1816, 10, ['Chris Bosh'])
#
# 637) (8292, 10, ['Michael Dougherty'])
#
# 638) (2252, 10, ['Seth Rogen'])
#
# 639) (573, 10, ['Dominic Monaghan'])
#
# 640) (336, 10, ['Michelle Obama'])
#
# 641) (2725, 10, ['Lalo Schifrin'])
#
# 642) (7093, 10, ['Jordan White'])
#
# 643) (1674, 10, ['Neel Sethi'])
#
# 644) (4430, 10, ['Keith Ellison'])
#
# 645) (563, 10, ['Margaret Stohl'])
#
# 646) (7247, 10, ['Kumail Nanjiani'])
#
# 647) (4775, 10, ['Gregg Popovich'])
#
# 648) (3850, 10, ['Meghan Markle', 'Meghan , Duchess of Sussex'])
# 649) (4867, 10, ['Yogi Adityanath'])
#
# 650) (133, 10, ['Cress Williams'])
#
# 651) (4704, 10, ['Nikolaj Coster-Waldau'])
#
# 652) (6908, 10, ['Jeff Yang'])
#
# 653) (2736, 10, ['Sonny Bill Williams'])
#
# 654) (3552, 10, ['Super Dragon'])
#
# 655) (7328, 10, ['London Breed'])
#
# 656) (6851, 10, ['James Stevenson'])
#
# 657) (6186, 10, ['Geoff Keighley'])
#
# 658) (4793, 10, ['Brian May'])
#
# 659) (2723, 10, ['Kate Erbland'])
#
# 660) (8264, 10, ['Taapsee Pannu'])
#
# 661) (2424, 10, ['Gina Carano'])
#
# 662) (3557, 10, ['Aaron Rodgers'])
#
# 663) (2018, 10, ['Thomas Wilson'])
#
# 664) (4616, 10, ['Keanu Reeves'])
#
# 665) (3999, 10, ['Eric Swalwell'])
#
# 666) (1917, 10, ['Jamal Murray'])
#
# 667) (4163, 10, ['Anne Hathaway'])
#
# 668) (1533, 10, ['Deborah Chow'])
#
# 669) (4747, 10, ['Wu Wenhui'])
#
# 670) (4970, 10, ['Naomi Ackie'])
#
# 671) (7240, 9, ['Komal Nahta'])
#
# 672) (8268, 9, ['Christoph Waltz'])
#
# 673) (2785, 9, ['Jaimie Alexander'])
#
# 674) (5109, 9, ['Elijah Wood'])
#
# 675) (4637, 9, ['Benjamin Netanyahu'])
#
# 676) (7812, 9, ['Porter Bibb'])
#
# 677) (1920, 9, ["Sean O'Connell"])
#
# 678) (6888, 9, ['Stephen Amell'])
#
# 679) (3760, 9, ['Josh Trank'])
#
# 680) (4112, 9, ['Bruce Boxleitner'])
#
# 681) (3892, 9, ['George Osborne'])
#
# 682) (1002, 9, ['Tobey Maguire'])
#
# 683) (452, 9, ['Zach Galligan'])
#
# 684) (963, 9, ['William Shatner'])
#
# 685) (5006, 9, ['Andrew Cripps'])
#
# 686) (6840, 9, ['James Earl Jones', 'James Jones'])
#
# 687) (2487, 9, ['Lily Cole'])
#
# 688) (221, 9, ['Dennis Gassner'])
#
# 689) (2905, 9, ['Wil Wheaton'])
#
# 690) (5215, 9, ['Bill de Blasio'])
#
# 691) (8012, 9, ['Ross Miller'])
#
# 692) (7248, 9, ['Jim Cramer'])
#
# 693) (537, 9, ['Steve Loney'])
#
# 694) (3284, 9, ['Jesper Nielsen'])
#
# 695) (3786, 9, ['Liam Hemsworth'])
#
# 696) (982, 9, ['Lin-Manuel Miranda'])
#
# 697) (1704, 9, ['Pahlaj Nihalani'])
#
# 698) (4069, 9, ['Joe Johnston'])
#
# 699) (4974, 9, ['Daniel Salmon'])
#
# 700) (6248, 9, ['Jim Bell'])
#
# 701) (4235, 9, ['Johnny Depp'])
#
# 702) (5645, 9, ['Alexander the Great'])
#
# 703) (8665, 9, ['Michael Mauer'])
#
# 704) (1551, 9, ['Sam Adams'])
#
# 705) (2994, 9, ['John McTiernan'])
#
# 706) (4776, 9, ['Patty Jenkins'])
#
# 707) (5434, 9, ['Ezra Miller'])
#
# 708) (2354, 9, ['Viola Davis'])
#
# 709) (4493, 9, ['Mel Gibson'])
#
# 710) (2981, 9, ['Dany Garcia'])
#
# 711) (6492, 9, ['David Walker'])
#
# 712) (59, 9, ['Mike Colter'])
#
# 713) (698, 9, ['Mary Jane'])
#
# 714) (5567, 9, ['Patricia Fox'])
#
# 715) (1361, 9, ['Sarah Kate Ellis'])
#
# 716) (7818, 9, ['Prasoon Joshi'])
#
# 717) (4575, 9, ['Kieran Harvey'])
#
# 718) (3576, 9, ['Don McGregor'])
#
# 719) (3731, 9, ['Jeff Wadlow'])
#
# 720) (3202, 9, ['Barbara Bry'])
#
# 721) (51, 9, ['Matteo Salvini'])
#
# 722) (7633, 9, ['Tom DeFalco', 'Tom Defalco'])
#
# 723) (3960, 9, ['Pom Klementieff'])
#
# 724) (1481, 9, ['Kevin Johnson'])
#
# 725) (3514, 9, ['Bob Kuhn'])
#
# 726) (1245, 9, ['Theodore Mascarenhas'])
#
# 727) (7027, 9, ['John Hennessey'])
#
# 728) (2007, 9, ['Nyle DiMarco'])
#
# 729) (46, 9, ['Paul Ward'])
#
# 730) (3399, 9, ['Erik Stevens'])
#
# 731) (912, 9, ['Joel Harlow'])
#
# 732) (6257, 9, ['Oprah Winfrey'])
#
# 733) (1915, 9, ['LEE RIDLEY', 'Lost Voice Guy', 'Lee Ridley'])
#
# 734) (5998, 9, ['Eric Hamilton'])
#
# 735) (6867, 9, ['Janine Jackson'])
#
# 736) (376, 9, ['Karen Jones'])
#
# 737) (5762, 9, ['David Hale'])
#
# 738) (4058, 9, ['David Michelinie'])
#
# 739) (1318, 9, ['Jim Martin'])
#
# 740) (7641, 9, ['Noah Pollak'])
#
# 741) (4701, 9, ['Triple H'])
#
# 742) (1091, 9, ['Jake Kasdan'])
#
# 743) (942, 9, ['Tony Revolori'])
#
# 744) (145, 9, ['Troy Baker'])
#
# 745) (3721, 9, ['Alan Menken'])
#
# 746) (8132, 9, ['Sean Keane'])
#
# 747) (5920, 9, ['Emma Thompson'])
#
# 748) (6320, 9, ['Rebecca Roanhorse'])
#
# 749) (5045, 9, ['Anna Boden'])
#
# 750) (6689, 9, ['Jack Nicholson'])
#
# 751) (7524, 9, ['Miguel Sapochnik'])
#
# 752) (6222, 9, ['Brian Burns'])
#
# 753) (5305, 9, ['Brian Volk-Weiss'])
#
# 754) (8536, 9, ['Charlotte Mitchell'])
#
# 755) (79, 8, ['Pastor Chris'])
#
# 756) (7844, 8, ['Raghubar Das'])
#
# 757) (1411, 8, ['Brian Smith'])
#
# 758) (2276, 8, ['Jeb Bush'])
#
# 759) (7561, 8, ['Michael Thomas', 'Mike Thomas'])
#
# 760) (1368, 8, ['Sarah Michelle Gellar'])
#
# 761) (6854, 8, ['Jamie Graham'])
#
# 762) (2183, 8, ['Seth Jacobs'])
#
# 763) (3635, 8, ['Lupe Fiasco'])
#
# 764) (2897, 8, ['Harry Scoble'])
#
# 765) (8258, 8, ['Suzanne Collins'])
#
# 766) (823, 8, ['Anne Thompson'])
#
# 767) (8327, 8, ['Tim Palen'])
#
# 768) (1243, 8, ['Jessica Jones'])
#
# 769) (5134, 8, ["Conan O'Brien"])
#
# 770) (360, 8, ['Lucy Lawless'])
#
# 771) (5687, 8, ['Susan Snow'])
#
# 772) (2894, 8, ['Debbie Reynolds'])
#
# 773) (878, 8, ['Ian Doescher'])
#
# 774) (35, 8, ['Mel Brooks'])
#
# 775) (148, 8, ['Russell Wilson'])
#
# 776) (3697, 8, ['Iain McCaig'])
#
# 777) (8026, 8, ['Russell Moore'])
#
# 778) (7660, 8, ['Gene Kranz'])
#
# 779) (4584, 8, ['Alex Kurtzman'])
#
# 780) (4309, 8, ['Daniel Radcliffe'])
#
# 781) (1015, 8, ['Simon Coveney'])
#
# 782) (670, 8, ['Deepika Padukone'])
#
# 783) (196, 8, ['Mike Johnson'])
#
# 784) (2505, 8, ['Alexander Lukashevich'])
#
# 785) (3371, 8, ['Bobby Moynihan'])
#
# 786) (4674, 8, ['Chris Jericho', 'CHRIS JERICHO'])
#
# 787) (8220, 8, ['Stephen Miller', 'Steve Miller'])
#
# 788) (5466, 8, ['Chip Zdarsky'])
#
# 789) (2205, 8, ['David Letterman'])
#
# 790) (7823, 8, ['John Ostrander'])
#
# 791) (2291, 8, ['Karen Fukuhara'])
#
# 792) (4811, 8, ['Terry Pratchett'])
#
# 793) (5928, 8, ['Nicholas Barber'])
#
# 794) (1641, 8, ['Jack Shepherd'])
#
# 795) (7038, 8, ['John Kani'])
#
# 796) (1700, 8, ['Malkia Cyril'])
#
# 797) (2072, 8, ['John Jennings'])
#
# 798) (3401, 8, ['Tomi Adeyemi'])
#
# 799) (8174, 8, ['Atiku Abubakar'])
#
# 800) (2572, 8, ['Laura Harrier'])
#
# 801) (4072, 8, ['Abhishek Manu Singhvi'])
#
# 802) (2532, 8, ['David Griffin'])
#
# 803) (4946, 8, ['Mike Pompeo'])
#
# 804) (5372, 8, ['James Meredith'])
#
# 805) (8134, 8, ['Sean Nolan'])
#
# 806) (3119, 8, ['R. Ball'])
#
# 807) (5537, 8, ['Daniel Kaluuya'])
#
# 808) (6479, 8, ['Kayla Reed'])
#
# 809) (3381, 8, ['Danny Danon'])
#
# 810) (1621, 8, ['Ray Fisher'])
#
# 811) (44, 8, ['Cathy Schulman'])
#
# 812) (2449, 8, ["Louis D'Esposito"])
#
# 813) (8049, 8, ['Saladin Ahmed'])
#
# 814) (5493, 8, ['Chris Hill'])
#
# 815) (3687, 8, ['Anil Kapoor'])
#
# 816) (1926, 8, ['Christine McCarthy'])
#
# 817) (8294, 8, ['Vladimir Putin'])
#
# 818) (3123, 8, ['Jamil Smith'])
#
# 819) (8486, 8, ['Tommy Wiseau'])
#
# 820) (5328, 8, ['Rachel Skarsten'])
#
# 821) (3980, 8, ['Fernando Meirelles'])
#
# 822) (2989, 8, ['Delilah S. Dawson'])
#
# 823) (446, 8, ['Angelina Jolie'])
#
# 824) (7010, 8, ['John Campea'])
#
# 825) (4216, 8, ['Robert De Niro'])
#
# 826) (2023, 7, ['Hadi Partovi'])
#
# 827) (3955, 7, ['Pierre Coffin'])
#
# 828) (2264, 7, ['Jimmy Takter'])
#
# 829) (5188, 7, ['Bibek Debroy'])
#
# 830) (1842, 7, ['Ted Cruz'])
#
# 831) (1619, 7, ['Danny Elfman'])
#
# 832) (4933, 7, ['Alexander Hug'])
#
# 833) (2456, 7, ['Janelle Monáe', 'Janelle Monae'])
#
# 834) (2563, 7, ['Eric Hawkins'])
#
# 835) (1992, 7, ['Adam Day'])
#
# 836) (8233, 7, ['Steven Molaro'])
#
# 837) (7874, 7, ['Roger Christian'])
#
# 838) (2059, 7, ['Chris Cooper', 'Christopher Cooper'])
#
# 839) (1465, 7, ['Alan Bergman'])
#
# 840) (4393, 7, ['Robert Smith', 'Robbie Smith'])
#
# 841) (4289, 7, ['Ivan Reitman'])
#
# 842) (748, 7, ['Michael Kaplan'])
#
# 843) (4253, 7, ['Federica Mogherini'])
#
# 844) (1737, 7, ['Chris Conley'])
#
# 845) (6432, 7, ['Christopher Stevens', 'Chris Stevens'])
#
# 846) (4605, 7, ['Henry Jenkins'])
#
# 847) (8469, 7, ['Monica Bellucci'])
#
# 848) (7719, 7, ['Paul Southern'])
#
# 849) (6690, 7, ['Jim Jordan'])
#
# 850) (2559, 7, ['Chris Weitz'])
#
# 851) (6845, 7, ['James Ohlen'])
#
# 852) (3650, 7, ['Tyrese Gibson'])
#
# 853) (7753, 7, ['Peter Howell'])
#
# 854) (8649, 7, ['Greg Berlanti'])
#
# 855) (5121, 7, ['Bear Grylls'])
#
# 856) (3851, 7, ['Melissa Harris-Perry'])
#
# 857) (3117, 7, ['Yannick Gingras'])
#
# 858) (1853, 7, ['Richard Kind'])
#
# 859) (1042, 7, ['Lucy Jones'])
#
# 860) (467, 7, ['Jamie Oliver'])
#
# 861) (8172, 7, ['Smriti Irani'])
#
# 862) (4437, 7, ['Mary Ann'])
#
# 863) (3011, 7, ['Terry Crews'])
#
# 864) (7125, 7, ['Robert Garcia'])
#
# 865) (6893, 7, ['William Shakespeare'])
#
# 866) (6602, 7, ['Craig Stevens'])
#
# 867) (4295, 7, ['Jason Jones'])
#
# 868) (6022, 7, ['Henry Cuellar'])
#
# 869) (487, 7, ['Franklin Graham'])
#
# 870) (5540, 7, ['Dr. John'])
#
# 871) (304, 7, ['Michael Burns'])
#
# 872) (4831, 7, ['Anushka Sharma'])
#
# 873) (7931, 7, ['Rick Remender'])
#
# 874) (1371, 7, ['Secret Cinema'])
#
# 875) (2810, 7, ['Joanna Lumley'])
#
# 876) (6285, 7, ['Jackie Shroff'])
#
# 877) (2349, 7, ['Mary J. Blige'])
#
# 878) (31, 7, ['John McCain'])
#
# 879) (2409, 7, ['Gabrielle Union'])
#
# 880) (6566, 7, ['Jerry Siegel'])
# 881) (5940, 7, ['Eddie Cunningham'])
#
# 882) (661, 7, ['Mike Huckabee'])
#
# 883) (4553, 7, ['Kyle Buchanan'])
#
# 884) (6544, 7, ['Kourtney Kardashian'])
#
# 885) (6685, 7, ['Greg Kelley'])
#
# 886) (2531, 7, ['Tom Brady'])
#
# 887) (2630, 7, ['Devan Coggan'])
#
# 888) (3005, 7, ['Pamela McClintock'])
#
# 889) (1032, 7, ['Stephen Galloway'])
#
# 890) (3222, 7, ['Joel Kinnaman'])
#
# 891) (654, 7, ['Richard Suckle'])
#
# 892) (3240, 7, ['Leslie Jones'])
#
# 893) (3790, 7, ['Chloe Bennet'])
#
# 894) (5217, 7, ['Billy Graham'])
#
# 895) (2913, 7, ['Laura Ingraham'])
#
# 896) (7326, 7, ['Lizo Mzimba'])
#
# 897) (4599, 7, ['Steven Price'])
#
# 898) (2672, 7, ['Todd Nauck'])
#
# 899) (3110, 7, ['Lachlan Murdoch'])
#
# 900) (1815, 7, ['Woody Harrelson'])
#
# 901) (4248, 7, ['Maria Zakharova'])
#
# 902) (8384, 7, ['Travis Williams'])
#
# 903) (4434, 7, ['Zaw Htay'])
#
# 904) (6677, 7, ['Jasmina Wiemann'])
#
# 905) (3141, 7, ['Tom Butler'])
#
# 906) (8015, 7, ['Roy Cooper'])
#
# 907) (6291, 7, ['Greg Carr'])
#
# 908) (54, 7, ['Holly Hunter'])
#
# 909) (4301, 7, ['Johnny Gargano'])
#
# 910) (1012, 7, ['James Mathis'])
#
# 911) (3061, 7, ['Liam Payne'])
#
# 912) (7892, 7, ['Rich Donnelly'])
#
# 913) (6084, 7, ['Bobby Seale'])
#
# 914) (3837, 7, ['Mark Farrell'])
#
# 915) (3536, 7, ['Dan Miller'])
#
# 916) (3649, 7, ['Reginald Hudlin'])
#
# 917) (1111, 7, ['Ram Nath Kovind', 'Shri Ram Nath Kovind'])
#
# 918) (5426, 7, ['Steven Rogers'])
#
# 919) (6192, 7, ['James Li'])
#
# 920) (3815, 7, ['Lucian Grainge'])
#
# 921) (4567, 7, ['Sam Nazarian'])
#
# 922) (2104, 7, ['James Newton Howard'])
#
# 923) (7351, 7, ['Killer Mike'])
#
# 924) (7391, 7, ['Mark Field'])
#
# 925) (2217, 7, ['Lena Waithe'])
#
# 926) (1575, 7, ['Zak Penn'])
#
# 927) (8030, 7, ['Ryan Blaney'])
#
# 928) (1990, 7, ['Simone Missick'])
#
# 929) (5184, 7, ['Bevan Dufty'])
#
# 930) (3570, 7, ['Ron Nirenberg'])
#
# 931) (1068, 7, ['Michael Che'])
#
# 932) (6752, 7, ['Julian Roman'])
#
# 933) (6385, 7, ['Daniel Ballard'])
#
# 934) (1471, 7, ['Rick Armstrong'])
#
# 935) (6915, 7, ['Jemele Hill'])
#
# 936) (292, 7, ['Edward Norton'])
#
# 937) (3506, 7, ['Liam Gallagher'])
#
# 938) (3170, 7, ['Stephen King'])
#
# 939) (3114, 7, ['Gareb Shamus'])
#
# 940) (5873, 7, ['Wilson Bethel'])
#
# 941) (4535, 7, ['Amit Sharma'])
#
# 942) (924, 7, ["Michael O'Sullivan"])
#
# 943) (672, 7, ['Jean-Pierre Lacroix'])
#
# 944) (3184, 7, ['Charlie Wen'])
#
# 945) (3235, 7, ['Aleksi Briclot'])
#
# 946) (4238, 7, ['Martin McDonagh'])
#
# 947) (5982, 7, ['Emmanuel Uduaghan'])
#
# 948) (5022, 7, ['Andrew Webster'])
#
# 949) (3444, 7, ['Charlie Brooker'])
#
# 950) (8520, 7, ['Don Williams'])
#
# 951) (5399, 7, ['Cavan Scott'])
#
# 952) (7831, 7, ['Giancarlo Esposito'])
#
# 953) (1131, 7, ['Aditya Seal'])
#
# 954) (3400, 7, ['Lea Salonga'])
#
# 955) (7367, 7, ['Marc Sumerak'])
#
# 956) (2290, 7, ['Florence Pugh'])
#
# 957) (864, 7, ['Mark Bridges'])
#
# 958) (8468, 7, ['Ben Snow'])
#
# 959) (6827, 7, ['Jake Zim'])
#
# 960) (3495, 7, ['Sue Cameron'])
#
# 961) (6989, 7, ['Joel Klatt'])
#
# 962) (181, 6, ['David Cameron'])
#
# 963) (4537, 6, ['Robert Young'])
#
# 964) (8607, 6, ['Aamir Khan'])
#
# 965) (6093, 6, ['Denis Villeneuve'])
#
# 966) (5433, 6, ['Eric Stonestreet'])
#
# 967) (1163, 6, ['Kate Hudson'])
#
# 968) (7970, 6, ['Robert Lee'])
#
# 969) (1656, 6, ['Stephanie Sigman'])
#
# 970) (2215, 6, ['Jake Johnson'])
#
# 971) (3939, 6, ['Paul Dini'])
#
# 972) (4200, 6, ['Alan Ladd , Jr. .'])
#
# 973) (224, 6, ['Josh Gad'])
#
# 974) (1908, 6, ['Kathy Taylor'])
#
# 975) (6864, 6, ['Jane Kim'])
#
# 976) (5436, 6, ['Charles Ross'])
#
# 977) (7982, 6, ['Robin Hood'])
#
# 978) (834, 6, ['Jean Shafiroff'])
#
# 979) (2521, 6, ['Barbara Broccoli'])
#
# 980) (1472, 6, ['Jim Darling'])
#
# 981) (6560, 6, ['Himanta Biswa Sarma'])
#
# 982) (5444, 6, ['Phyllis Smith'])
#
# 983) (727, 6, ['Dana Goldberg'])
#
# 984) (6990, 6, ['Joel Manby'])
#
# 985) (3334, 6, ['Kate McCarthy'])
#
# 986) (1311, 6, ['Peter Young'])
#
# 987) (1336, 6, ['Joseph Gordon-Levitt'])
#
# 988) (3475, 6, ['Nicholas Hoult'])
#
# 989) (5236, 6, ['Bob Johnson'])
#
# 990) (1324, 6, ['Jim Morris'])
#
# 991) (15, 6, ['Kurt Russell'])
#
# 992) (8506, 6, ['Brad Meltzer'])
#
# 993) (545, 6, ['Nkosazana Dlamini-Zuma'])
#
# 994) (5896, 6, ['Donald Clarke'])
#
# 995) (2983, 6, ['Jordan Randall'])
#
# 996) (1461, 6, ['Andy Palmer'])
#
# 997) (101, 6, ['George Takei'])
#
# 998) (8564, 6, ['Simon Reynolds'])
#
# 999) (943, 6, ['Mackenzie Davis'])
#
# 1000) (1968, 6, ['Maria Sand'])
#
# 1001) (5403, 6, ['Biz Markie'])
#
# 1002) (8194, 6, ['Stephen Dalton'])
#
# 1003) (8544, 6, ['Drew Goddard'])
#
# 1004) (5011, 6, ['Andy Kelly'])
#
# 1005) (7538, 6, ['Mike Francesa'])
#
# 1006) (5247, 6, ['Robert Irvine'])
#
# 1007) (3555, 6, ['Aaron Paul'])
#
# 1008) (1365, 6, ['Dolly Parton'])
#
# 1009) (4703, 6, ['Franz Beckenbauer'])
#
# 1010) (1440, 6, ['Joe Cressy'])
#
# 1011) (2127, 6, ['James Armstrong'])
#
# 1012) (8635, 6, ['Wolfgang Porsche'])
#
# 1013) (8466, 6, ['Ben Carson'])
#
# 1014) (1179, 6, ['Ian McKellen'])
#
# 1015) (6030, 6, ['Etela Rajender'])
#
# 1016) (4223, 6, ['Damian Keogh'])
#
# 1017) (2823, 6, ['Lev Grossman'])
#
# 1018) (4055, 6, ['Raman Singh'])
#
# 1019) (3098, 6, ['David Garcia'])
#
# 1020) (4849, 6, ['Adam Blackwell'])
#
# 1021) (675, 6, ['Sara Maria Forsberg'])
#
# 1022) (2761, 6, ['Brian Tyler'])
#
# 1023) (5176, 6, ['Benny Lim'])
#
# 1024) (4924, 6, ['Alex Hamilton'])
#
# 1025) (498, 6, ['Elizabeth Henstridge'])
#
# 1026) (7315, 6, ['Lisa Anderson'])
#
# 1027) (4721, 6, ['Lindsay Lohan'])
#
# 1028) (8594, 6, ['Elden Henson'])
#
# 1029) (5898, 6, ['Donna Frye'])
#
# 1030) (2299, 6, ['John Oliver'])
#
# 1031) (2724, 6, ['Jack Horner'])
#
# 1032) (722, 6, ['Brett Usher'])
#
# 1033) (6691, 6, ['H. Liu'])
#
# 1034) (4158, 6, ['Zayn Malik'])
#
# 1035) (2275, 6, ['Sam Miller'])
#
# 1036) (6223, 6, ['Gil Robertson'])
#
# 1037) (850, 6, ['Ahmed Hussen'])
#
# 1038) (2623, 6, ['Graeme McMillan'])
#
# 1039) (8638, 6, ['Kurt Busiek'])
#
# 1040) (1115, 6, ['John Horn'])
#
# 1041) (1011, 6, ['Wesley Morris'])
#
# 1042) (7942, 6, ['Rob Friedman'])
#
# 1043) (769, 6, ['Brian Curley'])
#
# 1044) (1418, 6, ['Alan Cohen'])
#
# 1045) (6047, 6, ['Alex Garland'])
#
# 1046) (1400, 6, ['George R. R. Martin'])
#
# 1047) (798, 6, ['Vicki Buck'])
#
# 1048) (2221, 6, ['Guillermo del Toro'])
#
# 1049) (7271, 6, ['Major Nelson'])
#
# 1050) (1716, 6, ['Victoria Beckham'])
#
# 1051) (5548, 6, ['Christopher Lee'])
#
# 1052) (6611, 6, ['Tony Hicks'])
#
# 1053) (4785, 6, ['Rodrigo Duterte'])
#
# 1054) (3881, 6, ['Larry the Cable Guy', 'Larry The Cable Guy'])
#
# 1055) (6722, 6, ['Patrick Leahy'])
#
# 1056) (6523, 6, ['Andrea Zimmerman'])
#
# 1057) (5666, 6, ['Kenneth Ward'])
#
# 1058) (507, 6, ['Jim Shooter'])
#
# 1059) (4339, 6, ['Maryann Brandon'])
#
# 1060) (2186, 6, ['Jonathan Anderson'])
#
# 1061) (6514, 6, ['Francisco Herrera'])
#
# 1062) (4692, 6, ['John Cena'])
#
# 1063) (5936, 6, ['Ed Skrein'])
#
# 1064) (1413, 6, ['Paul Hanneman'])
#
# 1065) (5181, 6, ['John Debney'])
#
# 1066) (6887, 6, ['will Miller'])
#
# 1067) (3469, 6, ['Rick Ross'])
#
# 1068) (5938, 6, ['Richard Posner'])
#
# 1069) (6039, 6, ['Garth Ennis'])
#
# 1070) (4017, 6, ['Snow White'])
#
# 1071) (3561, 6, ['Jonathan Sánchez'])
#
# 1072) (1556, 6, ['Dan DeLeeuw'])
#
# 1073) (4602, 6, ['Alexander Hamilton'])
#
# 1074) (5101, 6, ['Ayan Mukerji'])
#
# 1075) (8140, 6, ['Zack Stentz'])
#
# 1076) (5917, 6, ['Drew McWeeny'])
#
# 1077) (2591, 6, ['Kyle Smith'])
#
# 1078) (1776, 6, ['Brianna Hildebrand'])
#
# 1079) (8612, 6, ["Don `` The Dragon '' Wilson"])
#
# 1080) (8439, 6, ['William Nichols'])
#
# 1081) (361, 6, ['Ozzy Osbourne'])
#
# 1082) (4374, 6, ['Michael Nathanson'])
#
# 1083) (4682, 6, ['Mark Salisbury'])
#
# 1084) (3679, 6, ['Jonah Hill'])
#
# 1085) (5951, 6, ['Leslie Uggams'])
#
# 1086) (3670, 6, ['Stephen Lang'])
#
# 1087) (1344, 6, ['Kareem Abdul-Jabbar'])
#
# 1088) (3332, 6, ['Paul Watson', 'Paul Joseph Watson'])
#
# 1089) (3367, 6, ['Sam Katz'])
#
# 1090) (4100, 6, ['Will Arnett'])
#
# 1091) (8082, 6, ['Sarbananda Sonowal'])
#
# 1092) (3540, 6, ['Daniel Pineda'])
#
# 1093) (678, 6, ['Michelle Pfeiffer'])
#
# 1094) (4169, 6, ['Amarinder Singh'])
#
# 1095) (6181, 6, ['Gemma Chan'])
#
# 1096) (5115, 6, ['Dana Schwartz'])
#
# 1097) (2358, 6, ['Octavia Spencer'])
#
# 1098) (5839, 6, ['Dennis Archer'])
#
# 1099) (5129, 6, ['Barry Lyga'])
#
# 1100) (4142, 6, ['Jim Bridenstine'])
#
# 1101) (7666, 6, ['Alexander Gerst'])
#
# 1102) (5169, 6, ['Ben Shapiro'])
#
# 1103) (2743, 6, ['Michael Jai White'])
#
# 1104) (1181, 6, ['Alec Baldwin', 'ALEC BALDWIN'])
#
# 1105) (8392, 6, ['Evan Peters'])
#
# 1106) (1600, 6, ['Adam Milstein'])
#
# 1107) (8577, 6, ['Stephen Shin'])
#
# 1108) (8225, 6, ['Steve Sparks'])
#
# 1109) (4951, 6, ['Durga Shanker Mishra'])
#
# 1110) (2232, 6, ['Darren Cross'])
#
# 1111) (4344, 6, ['Miguel Mercado'])
#
# 1112) (1029, 6, ['Devendra Fadnavis'])
#
# 1113) (3479, 6, ['Mukesh Ambani'])
# 1114) (8197, 6, ['Stephen Brown'])
#
# 1115) (5858, 6, ['Dharmendra Pradhan'])
#
# 1116) (3624, 6, ['Kendra James'])
#
# 1117) (432, 6, ['Mark Webber'])
#
# 1118) (6117, 6, ['Domee Shi'])
#
# 1119) (7773, 6, ['Peter Sanderson'])
#
# 1120) (2649, 6, ['Justin Kroll'])
#
# 1121) (1499, 6, ['John Cooper'])
#
# 1122) (7861, 6, ['Randeep Surjewala'])
#
# 1123) (62, 6, ['Ranbir Kapoor'])
#
# 1124) (4145, 6, ['Jacinda Ardern'])
#
# 1125) (6700, 6, ['Robyn C. Spencer'])
#
# 1126) (6551, 6, ['Joshua Kim'])
#
# 1127) (6303, 6, ['Ian Malcolm'])
#
# 1128) (4021, 6, ['Spiro Razatos'])
#
# 1129) (8370, 6, ['Tommy Williams'])
#
# 1130) (8057, 6, ['Sam Shaw'])
#
# 1131) (4617, 6, ['Michael Murphy', 'Mike Murphy'])
#
# 1132) (6807, 6, ['Rodrigo Perez'])
#
# 1133) (5224, 6, ['Chris Fischer'])
#
# 1134) (4548, 6, ['Rob Letterman'])
#
# 1135) (3282, 6, ['Satyapal Singh'])
#
# 1136) (39, 6, ['Caryn James'])
#
# 1137) (3453, 6, ['Alexandre Ziegler'])
#
# 1138) (3166, 6, ['James Whitbrook'])
#
# 1139) (3130, 6, ['Alanna Smith'])
#
# 1140) (1520, 6, ['Austin Collins'])
#
# 1141) (959, 6, ['David Levine'])
#
# 1142) (3159, 6, ['Adrian Molina'])
#
# 1143) (1070, 6, ['Giriraj Singh'])
#
# 1144) (1095, 6, ['James Mattis', 'Jim Mattis'])
#
# 1145) (7105, 6, ['Josh Singer'])
#
# 1146) (4805, 6, ['Kevin Conroy'])
#
# 1147) (2845, 6, ['Rishi Kapoor'])
#
# 1148) (2828, 6, ['Kevin Burke'])
#
# 1149) (4443, 6, ['Mark Friedberg'])
#
# 1150) (8358, 6, ['Tom Herman'])
#
# 1151) (1697, 6, ['Siddharth Nigam'])
#
# 1152) (6953, 6, ['Jim Ryan'])
#
# 1153) (8112, 6, ['Sean Doolittle'])
#
# 1154) (7167, 6, ['Kayode Fayemi'])
#
# 1155) (4622, 6, ['Jimmy Bennett'])
#
# 1156) (2716, 6, ['Christopher Sean'])
#
# 1157) (3029, 6, ['Shreyas Talpade'])
#
# 1158) (5336, 6, ['Bryan Woods'])
#
# 1159) (3778, 6, ['Kevin Mayer'])
#
# 1160) (6755, 6, ['Kelvin Fletcher'])
#
# 1161) (7465, 6, ['Matthew Reinhart'])
#
# 1162) (1081, 6, ['Kaley Cuoco'])
#
# 1163) (659, 6, ['Peter Del Vecho', 'Peter del Vecho'])
#
# 1164) (4795, 6, ['Matthew Wood', 'Matt Wood'])
#
# 1165) (2373, 6, ['Rita Ora', 'RITA Ora'])
#
# 1166) (6392, 6, ['Sean Bailey'])
#
# 1167) (423, 6, ['Hossein Amini'])
#
# 1168) (6288, 6, ['Robin Lopez'])
#
# 1169) (1666, 6, ['Lloyd Jones'])
#
# 1170) (3875, 6, ['Carrie Beck'])
#
# 1171) (8274, 6, ['Tara Sutaria'])
#
# 1172) (6785, 5, ['50 Cent'])
#
# 1173) (6108, 5, ['Max Brallier'])
#
# 1174) (5551, 5, ['Christopher Orr'])
#
# 1175) (2231, 5, ['Jesse Eisenberg'])
#
# 1176) (669, 5, ['Vidya Balan'])
#
# 1177) (5972, 5, ['Ellen Margrethe Løj'])
#
# 1178) (7971, 5, ['Robert Lightfoot'])
#
# 1179) (1911, 5, ['Kyle Newman'])
#
# 1180) (4792, 5, ['Aaron Taylor-Johnson'])
#
# 1181) (6855, 5, ['Jamie Hendry'])
#
# 1182) (2642, 5, ['Ronda Rousey'])
#
# 1183) (7390, 5, ['Mark Ellis'])
#
# 1184) (4129, 5, ['Tom Baker'])
#
# 1185) (8295, 5, ['Andrew Kreisberg'])
#
# 1186) (5024, 5, ['Andrew White'])
#
# 1187) (6141, 5, ['Jock Reynolds'])
#
# 1188) (4934, 5, ['Alexis Ohanian'])
#
# 1189) (1041, 5, ['Jason Johnson'])
#
# 1190) (4480, 5, ['Gary Richardson'])
#
# 1191) (2376, 5, ['Tamra Judge'])
#
# 1192) (4317, 5, ['Santiago Fisas'])
#
# 1193) (2049, 5, ['Don Granger'])
#
# 1194) (2833, 5, ['Mary Fallin'])
#
# 1195) (3530, 5, ['Anthony Breznican'])
#
# 1196) (5186, 5, ['Terry McAuliffe'])
#
# 1197) (1762, 5, ['Ketan Patel'])
#
# 1198) (8425, 5, ['Jose Mourinho'])
#
# 1199) (2436, 5, ['Alan Stern'])
#
# 1200) (6159, 5, ['Gary Grant'])
#
# 1201) (4453, 5, ['Pat Marshall'])
#
# 1202) (122, 5, ['David Roberts'])
#
# 1203) (2726, 5, ['Greg Miller'])
#
# 1204) (7864, 5, ['Randy Hawes'])
#
# 1205) (7152, 5, ['Kate Muir'])
#
# 1206) (5001, 5, ['Subrata Mukherjee'])
#
# 1207) (2970, 5, ['David Koepp'])
#
# 1208) (1895, 5, ['Kyle Balda'])
#
# 1209) (7628, 5, ['Chris Roberts'])
#
# 1210) (6436, 5, ['Heather Brewer', 'Zac Brewer'])
#
# 1211) (760, 5, ['Chen Tien'])
#
# 1212) (6289, 5, ['Greg Abbott'])
#
# 1213) (8559, 5, ['Juan Antonio Bayona'])
#
# 1214) (3771, 5, ['Michael Jones', 'Mike Jones'])
#
# 1215) (6337, 5, ['Israel Sánchez'])
#
# 1216) (7520, 5, ['Rick McCallum'])
#
# 1217) (7763, 5, ['Jerry Brown'])
#
# 1218) (7095, 5, ['Joe Biden'])
#
# 1219) (6138, 5, ['Tim Schulte'])
#
# 1220) (4928, 5, ['Alex Ross Perry'])
#
# 1221) (3024, 5, ['Jason McGatlin'])
#
# 1222) (4057, 5, ['Ian Ziering'])
#
# 1223) (5597, 5, ['William Friedkin', 'WILLIAM FRIEDKIN'])
#
# 1224) (5602, 5, ['Richard Jones'])
#
# 1225) (1778, 5, ['Jenna Busch'])
#
# 1226) (1167, 5, ['John Kirby'])
#
# 1227) (2959, 5, ['Abdul Rahman'])
#
# 1228) (7639, 5, ['Noah Hawley'])
#
# 1229) (7102, 5, ['Josh Earnest'])
#
# 1230) (4347, 5, ['Donny Osmond'])
#
# 1231) (3243, 5, ['Chris Miller'])
#
# 1232) (4226, 5, ['David Brevik'])
#
# 1233) (8036, 5, ['Ryan Johnson'])
#
# 1234) (8069, 5, ['Sanjay Chauhan'])
#
# 1235) (2237, 5, ['Andrew Fisher'])
#
# 1236) (222, 5, ['Dennis Muren'])
#
# 1237) (1669, 5, ['Uhuru Kenyatta'])
#
# 1238) (5657, 5, ['Hitesh Patel'])
#
# 1239) (7413, 5, ['Anna Kendrick'])
#
# 1240) (5789, 5, ['David Miller'])
#
# 1241) (4700, 5, ['Frank Gibeau'])
#
# 1242) (624, 5, ['Gwynne Shotwell'])
#
# 1243) (106, 5, ['Jim Lovell'])
#
# 1244) (3678, 5, ['Alexandre Desplat'])
#
# 1245) (2351, 5, ['Sarah Silverman'])
#
# 1246) (5786, 5, ['David Martin'])
#
# 1247) (8330, 5, ['Tim Purpura'])
#
# 1248) (5455, 5, ['Che Fu'])
#
# 1249) (1080, 5, ['Don Ness'])
#
# 1250) (7123, 5, ['Chris Claremont'])
#
# 1251) (6490, 5, ['Peter Thornton'])
#
# 1252) (2637, 5, ['Terri Schwartz'])
#
# 1253) (7590, 5, ['Narendra Singh Tomar'])
#
# 1254) (4980, 5, ['Amy Miles'])
#
# 1255) (7697, 5, ['Paul Baker'])
#
# 1256) (6027, 5, ['David Cohen'])
#
# 1257) (3989, 5, ['Adam Yauch'])
#
# 1258) (3782, 5, ['Michelle Bachelet'])
#
# 1259) (2778, 5, ['Saif Ali Khan'])
#
# 1260) (1092, 5, ['James Courtney'])
#
# 1261) (7729, 5, ['Ken Chu'])
#
# 1262) (4154, 5, ['Mark Zuckerberg'])
#
# 1263) (3234, 5, ['Brian Miller'])
#
# 1264) (5826, 5, ['Deborah A. Miranda', 'Deborah Miranda'])
#
# 1265) (4830, 5, ['John Brown'])
#
# 1266) (2079, 5, ['Mike Hopkins'])
#
# 1267) (288, 5, ['Uwe Hück'])
#
# 1268) (8471, 5, ['Felipe Massa'])
#
# 1269) (7012, 5, ['Al Gough', 'Alfred Gough'])
#
# 1270) (1231, 5, ['Ben Morris'])
#
# 1271) (880, 5, ['Eric Williams'])
#
# 1272) (4233, 5, ['Dr. Robert'])
#
# 1273) (7455, 5, ['Matthew Berry'])
#
# 1274) (3586, 5, ['Edmond Mulet'])
#
# 1275) (1285, 5, ['Diane Corner'])
#
# 1276) (6589, 5, ['DAVID RAMSEY', 'David Ramsey'])
#
# 1277) (1535, 5, ['Luke Hemsworth'])
#
# 1278) (8626, 5, ['Lewis Hamilton'])
#
# 1279) (2425, 5, ['Christine Taylor'])
#
# 1280) (7275, 5, ['Larry Wilmore'])
#
# 1281) (10, 5, ['Sushant Singh Rajput'])
#
# 1282) (8350, 5, ['Tom Cullen'])
#
# 1283) (8494, 5, ["Nicole `` Snooki '' Polizzi"])
#
# 1284) (5440, 5, ['Ralph McQuarrie'])
#
# 1285) (6185, 5, ['Scott Walker'])
#
# 1286) (5097, 5, ['Lisa Cannon'])
#
# 1287) (2465, 5, ['Chris Pine'])
#
# 1288) (2764, 5, ['Will Leitch'])
#
# 1289) (1247, 5, ['Marco Grob'])
#
# 1290) (3927, 5, ['Tyler Durden'])
#
# 1291) (3456, 5, ['Terrence Howard'])
#
# ...
#
# 8241) (7276, 1, ['Larry Young'])
#
# 8242) (4781, 1, ['Jonathan Kay'])
#
# 8243) (3604, 1, ['Evan Goldberg'])
#
# 8244) (7298, 1, ['Zelina Vega'])
#
# 8245) (3798, 1, ['Lisa MacLeod'])
#
# 8246) (8503, 1, ['BARBIE Forteza'])
#
# 8247) (8473, 1, ['Han Kuo-yu'])
#
# 8248) (4715, 1, ['Chris Jacobs'])
#
# 8249) (4149, 1, ['Dusty Rhodes'])
#
# 8250) (2236, 1, ['Doug Wright'])
#
# 8251) (4552, 1, ['Laura Bailey'])
#
# 8252) (1388, 1, ['Puddles Pity Party'])
#
# 8253) (3913, 1, ['Noah Segan'])
#
# 8254) (3614, 1, ['Jonny Quinn'])
#
# 8255) (2155, 1, ['Andrew Hicks'])
#
# 8256) (1862, 1, ['Gucci Mane'])
#
# 8257) (8240, 1, ['Rob Delaney'])
#
# 8258) (8382, 1, ['Touraj Atabaki'])
#
# 8259) (8192, 1, ['Stephen Broden'])
#
# 8260) (7747, 1, ['Lorne Lanning'])
#
# 8261) (6653, 1, ['Josh Tenorio'])
#
# 8262) (2235, 1, ['B. Kline'])
#
# 8263) (1119, 1, ['Mr. Charles'])
#
# 8264) (5771, 1, ['David Itzkoff'])
#
# 8265) (7049, 1, ["John O'Shea"])
#
# 8266) (4402, 1, ['Sean Morrison'])
#
# 8267) (6182, 1, ['Pamela Kelly'])
#
# 8268) (5659, 1, ['Daggubati Suresh Babu'])
#
# 8269) (7457, 1, ['Matthew Green'])
#
# 8270) (7382, 1, ['Mark Allen'])
#
# 8271) (2584, 1, ['Kevin Curran'])
#
# 8272) (2812, 1, ['Brent Smith'])
#
# 8273) (1685, 1, ['Nathalie Boltt'])
#
# 8274) (5791, 1, ['David Newman'])
#
# 8275) (7278, 1, ['Dan Savage'])
#
# 8276) (4595, 1, ['Michael Avenatti'])
#
# 8277) (6901, 1, ['Jeff Smith'])
#
# 8278) (3509, 1, ['Cesar Torres'])
#
# 8279) (8224, 1, ['Steve Rushin'])
#
# 8280) (6238, 1, ['Glen Zipper'])
#
# 8281) (6740, 1, ['Andrea Young'])
#
# 8282) (1037, 1, ['Ilana Glazer'])
#
# 8283) (4709, 1, ['Karan Deol'])
#
# 8284) (2796, 1, ['Michael Lombardi'])
#
# 8285) (368, 1, ['Archie Barton'])
#
# 8286) (8496, 1, ['Chris Daughtry'])
#
# 8287) (3027, 1, ['JODIE Marsh'])
#
# 8288) (3263, 1, ['Tad Stones'])
#
# 8289) (6082, 1, ['Frank Anderson'])
#
# 8290) (70, 1, ['Mick Foley'])
#
# 8291) (3378, 1, ['Zion Williamson'])
#
# 8292) (3467, 1, ['Claude-Eric Poiroux'])
#
# 8293) (378, 1, ['Kamal Khan'])
#
# 8294) (578, 1, ['Ron Paul'])
#
# 8295) (6143, 1, ['Gareth Johnson'])
#
# 8296) (18, 1, ['Mark Kelly'])
#
# 8297) (2113, 1, ['Pat Gleason'])
#
# 8298) (124, 1, ['Cole Sprouse'])
#
# 8299) (7851, 1, ['Rajiv Chilaka'])
#
# 8300) (7128, 1, ['Justin Thompson'])
#
# 8301) (1655, 1, ['David Marcus'])
#
# 8302) (4832, 1, ['Sharmila Tagore'])
#
# 8303) (8006, 1, ['Ronald Thomas'])
#
# 8304) (8450, 1, ['Om Puri'])
#
# 8305) (5983, 1, ['Emun Elliott'])
#
# 8306) (5182, 1, ['David Montgomery'])
#
# 8307) (821, 1, ['Charlamagne Tha God'])
#
# 8308) (3247, 1, ['Sean Liu'])
#
# 8309) (5256, 1, ['Brad Hazzard'])
#
# 8310) (4860, 1, ['Adam Schneider'])
#
# 8311) (389, 1, ['Danny Boyle'])
#
# 8312) (2720, 1, ['Andrew Nicholson'])
#
# 8313) (5555, 1, ['Jim Bean'])
#
# 8314) (4340, 1, ['Matt Rogers'])
#
# 8315) (584, 1, ['Blake Michael'])
#
# 8316) (6061, 1, ['Raja Gosnell'])
#
# 8317) (7261, 1, ['Lance Harris'])
#
# 8318) (4891, 1, ['Alan Gill'])
#
# 8319) (4636, 1, ['Neil Miller'])
#
# 8320) (8059, 1, ['Sam Stitt'])
#
# 8321) (4686, 1, ['Murray Walker'])
#
# 8322) (4806, 1, ['Mary King'])
#
# 8323) (3458, 1, ['Frank Welker'])
#
# 8324) (6383, 1, ['Joseph George'])
#
# 8325) (4113, 1, ['Alejandro Ramirez'])
#
# 8326) (753, 1, ['William Sager'])
#
# 8327) (473, 1, ['Mark Walker'])
#
# 8328) (2979, 1, ['Israel Adesanya'])
#
# 8329) (3364, 1, ['Eric Baker'])
#
# 8330) (7681, 1, ['Pat McAfee'])
#
# 8331) (2260, 1, ['Imee Marcos'])
#
# 8332) (8217, 1, ['Steve Geppi'])
#
# 8333) (4418, 1, ["Beto O'Rourke"])
#
# 8334) (8176, 1, ['Sophie Perry'])
#
# 8335) (8131, 1, ['Sean Buckley'])
#
# 8336) (5353, 1, ['Cameron Williams'])
#
# 8337) (1261, 1, ['Manuel Solis'])
#
# 8338) (6597, 1, ['Daniel Mays'])
#
# 8339) (5910, 1, ['Doug Larson'])
#
# 8340) (704, 1, ['Dan Robinson'])
#
# 8341) (4626, 1, ['Jason Spisak'])
#
# 8342) (5984, 1, ['Maszlee Malik'])
#
# 8343) (5028, 1, ['Atul Dodiya'])
#
# 8344) (6581, 1, ['William Gray'])
#
# 8345) (6790, 1, ['Isaac Mass'])
#
# 8346) (7454, 1, ['Matthew Ball'])
#
# 8347) (5415, 1, ['Jordan Fish'])
#
# 8348) (4949, 1, ['Allison Lynn'])
#
# 8349) (3654, 1, ['Seth Grahame-Smith'])
#
# 8350) (4292, 1, ['Christian Fonnesbech'])
#
# 8351) (1363, 1, ['Seth Moulton'])
#
# 8352) (8628, 1, ['Isaac Hempstead-Wright'])
#
# 8353) (3232, 1, ['Leanne Jones'])
#
# 8354) (907, 1, ['Barbara Gordon'])
#
# 8355) (2493, 1, ['John Wyatt'])
#
# 8356) (615, 1, ['Malcolm Nance'])
#
# 8357) (7283, 1, ['Laura Whitmore'])
#
# 8358) (5534, 1, ['Christa Faust'])
#
# 8359) (6144, 1, ['Alex Michaels'])
#
# 8360) (5883, 1, ['Dominic Green'])
#
# 8361) (7130, 1, ['John Abraham'])
# 8362) (317, 1, ['Zoltan Simon'])
#
# 8363) (6837, 1, ['James Francis'])
#
# 8364) (4702, 1, ['Sean Hood'])
#
# 8365) (5038, 1, ['Angad Bedi'])
#
# 8366) (7810, 1, ['Polly Morgan'])
#
# 8367) (2944, 1, ['Keith Evans'])
#
# 8368) (7437, 1, ['Matt Braunger'])
#
# 8369) (7492, 1, ['Michael Eury'])
#
# 8370) (721, 1, ['Patrick Gallagher'])
#
# 8371) (4859, 1, ['Adam Schefter'])
#
# 8372) (5750, 1, ['David Carson'])
#
# 8373) (4988, 1, ['Bob Kane'])
#
# 8374) (2798, 1, ['Eddie Izzard'])
#
# 8375) (6202, 1, ['Wong Kar Wai'])
#
# 8376) (3016, 1, ['Jonathan Eirich'])
#
# 8377) (5379, 1, ['Carlos Morales'])
#
# 8378) (6217, 1, ['he dong'])
#
# 8379) (7242, 1, ['Kris Lythgoe'])
#
# 8380) (4865, 1, ['Aditya Om'])
#
# 8381) (4090, 1, ['Iza Calzado'])
#
# 8382) (3338, 1, ['El Jones'])
#
# 8383) (2488, 1, ['Taraji P. Henson'])
#
# 8384) (3795, 1, ['Shawn Levy'])
#
# 8385) (8179, 1, ['Srijit Mukherji'])
#
# 8386) (3004, 1, ['Linda Larkin'])
#
# 8387) (125, 1, ['Philip Ellis'])
#
# 8388) (7447, 1, ['Matt Morrison'])
#
# 8389) (4404, 1, ['Shruti Sharma'])
#
# 8390) (7914, 1, ['Richard Marles'])
#
# 8391) (8007, 1, ['Ronald Tubid'])
#
# 8392) (7663, 1, ['Robert Del Naja'])
#
# 8393) (339, 1, ['Idongesit Nkanga'])
#
# 8394) (4524, 1, ['Sarah Schachner'])
#
# 8395) (7937, 1, ['Ritesh Sidhwani'])
#
# 8396) (5197, 1, ['Bill George'])
#
# 8397) (6839, 1, ['James Hickey'])
#
# 8398) (3267, 1, ['Jasminder Singh'])
#
# 8399) (7259, 1, ['Lakshmi Parvathi'])
#
# 8400) (5248, 1, ['Bobby Tonelli'])
#
# 8401) (7358, 1, ['Makarand Deshpande'])
#
# 8402) (4989, 1, ['Slavoj Žižek'])
#
# 8403) (5751, 1, ['David Caspe'])
#
# 8404) (7987, 1, ['Rod Jones'])
#
# 8405) (6594, 1, ['Florian Henckel von Donnersmarck'])
#
# 8406) (7751, 1, ['Peter Gray'])
#
# 8407) (7582, 1, ['Na Kyung-won'])
#
# 8408) (4278, 1, ['Prashant Kumar'])
#
# 8409) (1865, 1, ['Isaac Larian'])
#
# 8410) (7469, 1, ['Max Lincoln'])
#
# 8411) (8485, 1, ['Richard Edlund'])
#
# 8412) (7600, 1, ['Shannon Lee'])
#
# 8413) (5130, 1, ['Barry McGovern'])
#
# 8414) (4041, 1, ['Chris Ngige'])
#
# 8415) (936, 1, ['Matt Walker'])
#
# 8416) (8319, 1, ['Tim Kelly'])
#
# 8417) (5291, 1, ['Brian Crecente'])
#
# 8418) (1297, 1, ['Ron Funches'])
#
# 8419) (3715, 1, ['R. A. Salvatore'])
#
# 8420) (5383, 1, ['Carol Harrison'])
#
# 8421) (3849, 1, ['DeWanda Wise'])
#
# 8422) (5759, 1, ['David Engel'])
#
# 8423) (6304, 1, ['Gregg Barnes'])
#
# 8424) (1591, 1, ['Jim Jarmusch'])
#
# 8425) (6344, 1, ['Andrew Hall'])
#
# 8426) (3041, 1, ['Bob Simpson'])
#
# 8427) (4706, 1, ['Sally Hunt'])
#
# 8428) (8283, 1, ['Terri Seymour'])
#
# 8429) (1026, 1, ['Joe Elliott'])
#
# 8430) (4122, 1, ['Kit Harington'])
#
# 8431) (3577, 1, ['Doug Johnson'])
#
# 8432) (6213, 1, ['John Langley'])
#
# 8433) (8200, 1, ['Stephen Hawley'])
#
# 8434) (4091, 1, ['Denise Laurel'])
#
# 8435) (3901, 1, ['Jim Grant'])
#
# 8436) (937, 1, ['Stephan James'])
#
# 8437) (2829, 1, ['Matthew De Abaitua'])
#
# 8438) (2494, 1, ['Candace Cameron Bure'])
#
# 8439) (1924, 1, ['Dominique Tipper'])
#
# 8440) (3250, 1, ['Jaren Jackson Jr. .'])
#
# 8441) (4689, 1, ['Nikki Novak'])
#
# 8442) (5634, 1, ['Craig Melvin'])
#
# 8443) (7553, 1, ['Mike Norton'])
#
# 8444) (7948, 1, ['Rob Owen'])
#
# 8445) (3508, 1, ['Swae Lee'])
#
# 8446) (2261, 1, ['Laura Dern'])
#
# 8447) (8501, 1, ['Robert Meyers'])
#
# 8448) (5156, 1, ['Ben Cline'])
#
# 8449) (1328, 1, ['Adam Rich'])
#
# 8450) (170, 1, ['Robbie Robertson'])
#
# 8451) (4680, 1, ['Hulk Hogan'])
#
# 8452) (7434, 1, ['Mason Plumlee'])
#
# 8453) (7236, 1, ['Kirk Jackson'])
#
# 8454) (5061, 1, ['Gary Lineker'])
#
# 8455) (5459, 1, ['Joan Crawford'])
#
# 8456) (3548, 1, ['David Mandel'])
#
# 8457) (5036, 1, ['Andy Whittaker'])
#
# 8458) (11, 1, ['Ilana Kaplan'])
#
# 8459) (1705, 1, ['Max Conze'])
#
# 8460) (8591, 1, ['Kurt Elling'])
#
# 8461) (5702, 1, ['Daniel Pemberton'])
#
# 8462) (3099, 1, ['Thomas Clark'])
#
# 8463) (3273, 1, ['Velveteen Dream'])
#
# 8464) (1394, 1, ['Brad Stevens'])
#
# 8465) (8103, 1, ['Scott Shaw'])
#
# 8466) (3667, 1, ['Hironobu Sakaguchi'])
#
# 8467) (3436, 1, ['Claudio Sanchez'])
#
# 8468) (7151, 1, ['Kartik Aaryan'])
#
# 8469) (5808, 1, ['David Unger'])
#
# 8470) (4670, 1, ['Peter Amory'])
#
# 8471) (2543, 1, ['Josh Luber'])
#
# 8472) (867, 1, ['Matt Taylor'])
#
# 8473) (4207, 1, ['Clive Carter'])
#
# 8474) (2417, 1, ['Bill Mantlo'])
#
# 8475) (1280, 1, ['Kirsty Gilmour'])
#
# 8476) (6928, 1, ['JESSE THOMAS'])
#
# 8477) (511, 1, ['Dee Dee'])
#
# 8478) (6995, 1, ['Alex Macdonald'])
#
# 8479) (2467, 1, ['Shay Mitchell'])
#
# 8480) (6056, 1, ['J. Michael Riva'])
#
# 8481) (5321, 1, ['Bruce Milne'])
#
# 8482) (162, 1, ['Danny Cannon'])
#
# 8483) (6028, 1, ['Nick Reynoldson'])
#
# 8484) (6814, 1, ['Jack Morelli'])
#
# 8485) (1295, 1, ['Tim Daniel'])
#
# 8486) (2094, 1, ['Gabriel Flores'])
#
# 8487) (2132, 1, ['Simon Barry'])
#
# 8488) (327, 1, ['R. Srinivasan'])
#
# 8489) (3982, 1, ['Steve Gibson'])
#
# 8490) (4900, 1, ['Alan Taylor'])
#
# 8491) (1881, 1, ['Brian Johnson'])
#
# 8492) (4586, 1, ['Girish Menon'])
#
# 8493) (5819, 1, ['Dean Kalimniou'])
#
# 8494) (6397, 1, ['Gulzar Ahmed'])
#
# 8495) (3261, 1, ['Daniel Naprous'])
#
# 8496) (2960, 1, ['Ian Palmer'])
#
# 8497) (4533, 1, ['Tom DeLonge'])
#
# 8498) (7944, 1, ['Rob Howard'])
#
# 8499) (1779, 1, ['Chris Dawson'])
#
# 8500) (4082, 1, ['Rob Marshall'])
#
# 8501) (5504, 1, ['Chris Lynch'])
#
# 8502) (5821, 1, ['Dean Martin'])
#
# 8503) (3908, 1, ['Nicole Kassell'])
#
# 8504) (7769, 1, ['Peter Rainer'])
#
# 8505) (639, 1, ['Stacy Martin'])
#
# 8506) (4570, 1, ['John Caldwell'])
#
# 8507) (7715, 1, ['Paul Lowe'])
#
# 8508) (7795, 1, ['Kevin Eastman'])
#
# 8509) (4735, 1, ['Ben Taylor'])
#
# 8510) (7618, 1, ['Nick Brown'])
#
# 8511) (5317, 1, ['Bruce Johnson'])
#
# 8512) (7945, 1, ['Rob Jefferies'])
#
# 8513) (386, 1, ['Courtney Jones'])
#
# 8514) (6327, 1, ['Desdemona Chiang'])
#
# 8515) (8115, 1, ['Sean Jones'])
#
# 8516) (4360, 1, ['Max Boot'])
#
# 8517) (588, 1, ['Tom Wood'])
#
# 8518) (7332, 1, ['Louis Marriott'])
#
# 8519) (4387, 1, ['Cori Gauff'])
#
# 8520) (6194, 1, ['Cameron Boyce'])
#
# 8521) (2942, 1, ['Storm Reid'])
#
# 8522) (4887, 1, ['Akiv Ali'])
#
# 8523) (690, 1, ['Joe Timmons'])
#
# 8524) (2043, 1, ['Sai Dharam Tej'])
#
# 8525) (2112, 1, ['Brad Weston'])
#
# 8526) (3460, 1, ['Gabriel Byrne'])
#
# 8527) (5506, 1, ['Chris Mason'])
#
# 8528) (2609, 1, ['Sam Morril'])
#
# 8529) (198, 1, ['David Baron'])
#
# 8530) (1729, 1, ['Rahul Kohli'])
#
# 8531) (6878, 1, ['Jason Palmer'])
#
# 8532) (4389, 1, ['Dianne Buswell'])
#
# 8533) (6971, 1, ['Joe Driscoll'])
#
# 8534) (2328, 1, ['Jose Perez'])
#
# 8535) (1906, 1, ['Sam Esmail'])
#
# 8536) (1925, 1, ['Tim Martin'])
#
# 8537) (7569, 1, ['Min-Liang Tan'])
#
# 8538) (6976, 1, ['Joe McHugh'])
#
# 8539) (7016, 1, ['John Doyle'])
#
# 8540) (8090, 1, ['Scott Clark'])
#
# 8541) (6870, 1, ['Jared Gutstadt'])
#
# 8542) (115, 1, ['Evans Revere'])
#
# 8543) (8005, 1, ['Ron Swoboda'])
#
# 8544) (3926, 1, ['Paul McGann'])
#
# 8545) (623, 1, ['Hugh Bonneville'])
#
# 8546) (8487, 1, ['Matt Ellison'])
#
# 8547) (8119, 1, ['Sean McDonnell'])
#
# 8548) (6983, 1, ['Joe Tessitore'])
#
# 8549) (220, 1, ['Dennis DeYoung'])
#
# 8550) (8510, 1, ["Dermot O'Leary"])
#
# 8551) (8204, 1, ['Stephen Oliver'])
#
# 8552) (2312, 1, ['Creed Bratton'])
#
# 8553) (1503, 1, ['Anita Sengupta'])
#
# 8554) (3574, 1, ['Oren Uziel'])
#
# 8555) (5671, 1, ['Dan Dunleavy'])
#
# 8556) (3651, 1, ['Hayden Schlossberg'])
#
# 8557) (2985, 1, ['Burk Sharpless'])
#
# 8558) (192, 1, ['David Roth'])
#
# 8559) (4955, 1, ['Amanda Keller'])
#
# 8560) (3408, 1, ['Ben Dreyfuss'])
#
# 8561) (7325, 1, ['Liz Macdonald'])
#
# 8562) (2851, 1, ['Gurinder Chadha'])
#
# 8563) (5865, 1, ['Diane Wood'])
#
# 8564) (4305, 1, ['Fan Bingbing'])
#
# 8565) (3473, 1, ['Michael Sheen'])
#
# 8566) (6175, 1, ['Wayne Newton'])
#
# 8567) (6128, 1, ['Nuhu Ribadu'])
#
# 8568) (3842, 1, ['Martin Rodriguez'])
#
# 8569) (1947, 1, ['Helen Whately'])
#
# 8570) (2804, 1, ['Fernando Perez-Miles'])
#
# 8571) (809, 1, ['Chris Spearman'])
#
# 8572) (140, 1, ['Hideki Miyazaki'])
#
# 8573) (2675, 1, ['Tom Peyer'])
#
# 8574) (3358, 1, ['Neshama Carlebach'])
#
# 8575) (1628, 1, ['Darnell Furlong'])
#
# 8576) (893, 1, ['Ian Pattison'])
#
# 8577) (8587, 1, ['Terrence Ross'])
#
# 8578) (2603, 1, ['Philip Parker'])
#
# 8579) (4426, 1, ['Song Lee'])
#
# 8580) (908, 1, ['Matt Grady'])
#
# 8581) (6457, 1, ['Barbara Sturm'])
#
# 8582) (242, 1, ['Derek Mackay'])
#
# 8583) (1637, 1, ['Pia Wurtzbach'])
#
# 8584) (5193, 1, ['Bill Carlson'])
#
# 8585) (5591, 1, ['George A. Romero'])
#
# 8586) (3181, 1, ['Becky Bresee'])
#
# 8587) (6903, 1, ['Jeff Tallon'])
#
# 8588) (3946, 1, ['Anne-Sophie Mutter'])
#
# 8589) (5019, 1, ['Ashish Gupta'])
#
# 8590) (4474, 1, ['Matt Cooper'])
#
# 8591) (8523, 1, ['Brian Bolland'])
#
# 8592) (6543, 1, ['Armin VahidMohammadi'])
#
# 8593) (3834, 1, ['Marie Leonard'])
#
# 8594) (3613, 1, ['Richard Knight'])
#
# 8595) (7885, 1, ['Rex Crowle'])
#
# 8596) (5283, 1, ['Brett Mitchell'])
#
# 8597) (6749, 1, ['Simon Robinson'])
#
# 8598) (2569, 1, ['Barbie Ferreira'])
# 8599) (2801, 1, ['Robert Forster'])
#
# 8600) (1723, 1, ['Claire Martin'])
#
# 8601) (385, 1, ['Richard Karn'])
#
# 8602) (7410, 1, ['Mark Spector'])
#
# 8603) (5574, 1, ['Clark Spencer'])
#
# 8604) (3111, 1, ['Saniyya Sidney'])
#
# 8605) (4153, 1, ['Arlene Gottfried'])
#
# 8606) (4851, 1, ['Adam Cole'])
#
# 8607) (2419, 1, ['Julianne Hough'])
#
# 8608) (7855, 1, ['Ralph Winter'])
#
# 8609) (5832, 1, ['Dele Momodu'])
#
# 8610) (4813, 1, ['Marcia Lucas'])
#
# 8611) (4916, 1, ['J.D. Miller'])
#
# 8612) (7514, 1, ['Michael Smith'])
#
# 8613) (4165, 1, ['Azita Ghanizada'])
#
# 8614) (7655, 1, ['Ong Ye Kung'])
#
# 8615) (2375, 1, ['Femi Oguns'])
#
# 8616) (5244, 1, ['Bob Thomas'])
#
# 8617) (204, 1, ['Dean Parisot'])
#
# 8618) (1513, 1, ['Thomas Jordan'])
#
# 8619) (2734, 1, ['Ben Mezrich'])
#
# 8620) (3030, 1, ['Mary Lambert'])
#
# 8621) (3283, 1, ['Paulo Lemos'])
#
# 8622) (3997, 1, ['Jonathan Frakes'])
#
# 8623) (2391, 1, ['Tobias Moers'])
#
# 8624) (2933, 1, ['Danny DeVito'])
#
# 8625) (4386, 1, ['Pseudonymous Bosch'])
#
# 8626) (6586, 1, ['Susanna Fournier'])
#
# 8627) (6604, 1, ['Grant Delpit'])
#
# 8628) (7181, 1, ['Kelly-Marie Stewart'])
#
# 8629) (6446, 1, ['Joe Turner'])
#
# 8630) (4874, 1, ['Sandra Harding'])
#
# 8631) (8235, 1, ['Steven T. Seagle'])
#
# 8632) (263, 1, ['Francisco Diaz'])
#
# 8633) (4232, 1, ['Doug Warren'])
#
# 8634) (5441, 1, ['Nick Maley'])
#
# 8635) (4237, 1, ['Glenn Close'])
#
# 8636) (5709, 1, ['Danny Santiago'])
#
# 8637) (3996, 1, ['Axel Braun'])
#
# 8638) (920, 1, ['Jason Love'])
#
# 8639) (2029, 1, ['Noelle Stevenson'])
#
# 8640) (3660, 1, ['Steven Taylor'])
#
# 8641) (2269, 1, ['Thomas R. Burman'])
#
# 8642) (6409, 1, ['Brian Walker'])
#
# 8643) (1074, 1, ['Matt Apuzzo'])
#
# 8644) (8513, 1, ['Tom Price'])
#
# 8645) (6844, 1, ['James Mylne'])
#
# 8646) (6861, 1, ['Jan Todd'])
#
# 8647) (6119, 1, ['Chris Glover'])
#
# 8648) (3476, 1, ['Jamie Costa'])
#
# 8649) (7453, 1, ['Matthew Baker'])
#
# 8650) (3009, 1, ['Stephanie Pratt'])
#
# 8651) (1290, 1, ['David Yarrow'])
#
# 8652) (6351, 1, ['Greta Thunberg'])
#
# 8653) (2904, 1, ['Vanessa Morgan'])
#
# 8654) (4741, 1, ['Travis Bean'])
#
# 8655) (3558, 1, ['Didi Gregorius'])
#
# 8656) (6295, 1, ['Greg McGee'])
#
# 8657) (6603, 1, ['Shimon Prokupecz'])
#
# 8658) (2509, 1, ['Qandeel Baloch'])
#
# 8659) (4691, 1, ['Yvette Nicole Brown'])
#
# 8660) (785, 1, ['Tedros Adhanom Ghebreyesus'])
#
# 8661) (8598, 1, ['Mookie Blaylock'])
#
# 8662) (4693, 1, ['Randy Orton'])
#
# 8663) (451, 1, ['Zach Galifianakis'])
#
# 8664) (3020, 1, ['Deanna Dwyer'])
#
# 8665) (2114, 1, ['Jason Isaacs'])
#
# 8666) (7201, 1, ['Kevin Cahoon'])
#
# 8667) (2042, 1, ['Fabien Riggall'])
#
# 8668) (3215, 1, ['Hunter Renfrow'])
#
# 8669) (2497, 1, ['Stuart Curtis'])
#
# 8670) (4268, 1, ['Joe Perry'])
#
# 8671) (5897, 1, ['Mike Pondsmith'])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-48-7533b07c0c82> in <module>
#       5 for n in range(N):
#       6
# ----> 7     idxs = [i for (i, shared) in enumerate(df.shared_ID) if shared == ID[n]]
#       8     associated_speakers = df.iloc[idxs, :].speaker.unique()
#       9
#
# <ipython-input-48-7533b07c0c82> in <listcomp>(.0)
#       5 for n in range(N):
#       6
# ----> 7     idxs = [i for (i, shared) in enumerate(df.shared_ID) if shared == ID[n]]
#       8     associated_speakers = df.iloc[idxs, :].speaker.unique()
#       9
#
# IndexError: index 8671 is out of bounds for axis 0 with size 8671
