# %% [markdown]
# ## Load Box Office, IMDb and Quotebank

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import plotly.express as px
import plotly

# %%
data_dir = os.getcwd() + os.sep + 'data'

df_Quotebank = pd.read_pickle(rf"{data_dir}{os.sep}Quotebank_full.pkl") 
df_boxOffice = pd.read_pickle(rf"{data_dir}{os.sep}boxOffice.pkl")

# %%
IMDbMovies = pd.read_csv(rf"{data_dir}{os.sep}IMDb{os.sep}IMDB movies.csv", low_memory=False)
IMDbRatings = pd.read_csv(rf"{data_dir}{os.sep}IMDb{os.sep}IMDB ratings.csv")    
df_IMDb = IMDbMovies.merge(IMDbRatings)

# %%
df_Quotebank.head(3)
# Out:
#                                            quotation         speaker  \
# 0  with the short and said, `We'd like to go with...         Al Jean
# 1  Thrilled to announce that I will perform the e...  Brandi Carlile
# 2  Sonic the Hedgehog might not become a kid-movi...    Brian Truitt
#
#           qids        date  numOccurrences  \
# 0   [Q2829373]  2020-02-28               1
# 1    [Q164060]  2020-02-19               1
# 2  [Q24387573]  2020-02-14               1
#
#                                               probas  \
# 0                [[None, 0.6415], [Al Jean, 0.3585]]
# 1  [[Brandi Carlile, 0.543], [None, 0.3348], [Myc...
# 2  [[None, 0.7308], [Brian Truitt, 0.179], [Micha...
#
#                                                 urls               movie  \
# 0  [https://comicbook.com/tv-shows/2020/02/28/the...              Onward
# 1  [https://klaw.com/brandi-carlile-carried-me-wi...              Onward
# 2  [http://www.gamespot.com/articles/sonic-the-he...  Sonic the Hedgehog
#
#    shared_ID AFINN_label  AFINN_score VADER_label  VADER_score BERT_label  \
# 0       3832    POSITIVE     0.285714    POSITIVE       0.7003   POSITIVE
# 1       1151    POSITIVE     0.135135    POSITIVE       0.6996   POSITIVE
# 2       3155    POSITIVE     0.166667    POSITIVE       0.8899   POSITIVE
#
#    posBERT_score  scaledBERT_score year-month
# 0       0.999716          0.889884    2020-02
# 1       0.999764          0.910927    2020-02
# 2       0.999813          0.937261    2020-02

# %%
df_boxOffice.head()
# Out:
#          days       dow  rank       daily  theaters special events    movie
# 0  2019-05-24    Friday     1  31358935.0      4476            NaN  Aladdin
# 1  2019-05-25  Saturday     1  30013295.0      4476            NaN  Aladdin
# 2  2019-05-26    Sunday     1  30128699.0      4476            NaN  Aladdin
# 3  2019-05-27    Monday     1  25305033.0      4476   Memorial Day  Aladdin
# 4  2019-05-28   Tuesday     1  12014982.0      4476            NaN  Aladdin

# %%
df_IMDb.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  ... females_30age_avg_vote  \
# 0     None                      Alexander Black  ...                    5.7
# 1     None                         Charles Tait  ...                    6.2
# 2      NaN                            Urban Gad  ...                    5.8
# 3  English                   Charles L. Gaskill  ...                    5.5
# 4  Italian  Francesco Bertolini, Adolfo Padovan  ...                    7.3
#
#   females_30age_votes females_45age_avg_vote females_45age_votes  \
# 0                13.0                    4.5                 4.0
# 1                23.0                    6.6                14.0
# 2                 4.0                    6.8                 7.0
# 3                14.0                    6.1                21.0
# 4                82.0                    7.4                77.0
#
#    top1000_voters_rating  top1000_voters_votes us_voters_rating  \
# 0                    5.7                  34.0              6.4
# 1                    6.4                  66.0              6.0
# 2                    5.4                  32.0              6.2
# 3                    4.9                  57.0              5.5
# 4                    6.9                 139.0              7.0
#
#   us_voters_votes non_us_voters_rating  non_us_voters_votes
# 0            51.0                  6.0                 70.0
# 1            96.0                  6.2                331.0
# 2            31.0                  5.9                123.0
# 3           207.0                  4.7                105.0
# 4           488.0                  7.0               1166.0
#
# [5 rows x 70 columns]

# %%
df_boxOffice['year-month'] = [("-").join(date.split("-")[:2]) for date in df_boxOffice['days']]
df_boxOffice['year-month'].unique()
# Out:
# array(['2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10',
#        '2018-12', '2019-01', '2019-02', '2019-03', '2019-04', '2015-05',
#        '2015-06', '2015-07', '2018-04', '2018-05', '2018-06', '2018-07',
#        '2018-08', '2018-09', '2020-01', '2020-02', '2020-03', '2016-03',
#        '2016-04', '2016-05', '2016-06', '2017-03', '2017-04', '2017-05',
#        '2017-06', '2017-07', '2018-02', '2018-03', '2018-11', '2016-07',
#        '2016-08', '2016-09', '2016-02', '2017-08', '2017-09', '2017-10',
#        '2017-11', '2017-12', '2016-11', '2016-12', '2017-01', '2017-02',
#        '2016-10', '2019-11', '2019-12', '2015-04', '2018-10', '2015-08',
#        '2015-09', '2015-10', '2018-01', '2015-11', '2015-12', '2016-01',
#        '2020-09', '2020-10', '2020-11', '2020-12', '2021-01', '2021-02',
#        '2021-03', '2021-04'], dtype=object)

# %%
def wrangleData(df):
    #Creating numerical movie keys
    keys = [i for i in range(df['movie'].unique().__len__())]

    # create sub-dataframes for each movie sorted by the time index
    all_dataframes = {}
    for i, movie in zip(keys, df['movie'].sort_values().unique()):
        df_temp = df[df['movie'] == movie].sort_values('year-month', ascending=True)
        all_dataframes[i] = df_temp
    
    # concatenating all sub-dataframes to a single dataframe
    concat_df = []
    for i in all_dataframes:
        concat_df.append(all_dataframes[i])

    df_wrangled = pd.concat(concat_df)
    
    return df_wrangled

# %%
def createPlotDF(df_all, attribute, y_label, N_samples=10, replace=True):
    """ takes as input; a dataframe, the sentiment name we wish to investigate as well as
    number of movies in the subsample and whether it should be done with replacement or not.
    
    return as a dataframe containing movie title for all time indeces (i.e. year-month) as well as 
    the mean sentiment related to that movie in that time slot. This mean sentiment is forced to zero if no quotes
    about a movie in the given time-index are found.
    """
    
    # selecting sub-sample if 'N_samples' argument is passed
    if N_samples == None:
        df_sample = df_all
    else:
        selected_movies = df_all['movie'].sample(N_samples, replace=replace).values.tolist()
        df_sample = df_all[df_all['movie'].isin(selected_movies)]
    
    df_plot = {}
    i = 0
    
    # creating data frame for visualization
    for movie in tqdm(df_sample.movie.unique()):
        acc_mean = 0
        for month in df_sample['year-month'].sort_values().unique():
            # checking whether movie/time-index pair exists in dataframe
            condition = np.logical_and(df_sample['year-month'] == month, df_sample['movie'] == movie)

            if condition.sum() == 0: # if movie and time-index does not occur together
                acc_mean += 0 
                
            else: # when movie and time-index occur together, mean the specified scores from that time-index
                #if attribute == 'posBERT_score':
                    #df_sample[attribute] = (df_sample[attribute] - 0.5) * 2 #for negative sentiment interpretation
                    
                acc_mean += df_sample[condition][attribute].sum()
            
            # add values to dataframe for plotting
            df_plot[i] = [month, movie, acc_mean]
            i += 1
    
    # creating dataframe and specifying column names
    df_plot = pd.DataFrame(df_plot).T
    df_plot.columns = ['month', 'movie', f'Avg. monthly {y_label}']

    return df_plot, df_sample

# %%
def animatedBarPlot(df_plot, y_label, title, speed=0.2):
    """ 
    speed must be between 0 and 1 where 1 is not included.
    """
    
    upper = np.round(df_plot.groupby('movie')[f'Avg. monthly {y_label}'].max())
    lower = np.round(df_plot.groupby('movie')[f'Avg. monthly {y_label}'].min())
    range_y = [0, np.round(upper + 0.05*upper)]

    fig = px.bar(df_plot, x='movie', y=f"Avg. monthly {y_label}", color="movie",
                  animation_frame="month", animation_group="movie", 
                  range_y=range_y,# orientation='h',
                  title=title)
    
    fig.layout.updatemenus[0].buttons[0].args[1]['frame']['duration'] = (1-speed) * 1000
    fig.layout.updatemenus[0].buttons[0].args[1]['transition']['duration'] = (1-speed) * 1000
    
    fig.show()
    
    return fig

# %%
y_label = 'box office revenue'
df_boxOffice_wrangled = wrangleData(df_boxOffice)
attribute = 'daily'
N_samples = 10
title = 'Accumulated Box Office revenue across time'

df_plot, df_sample= createPlotDF(df_boxOffice_wranlged, attribute=attribute, y_label=y_label, N_samples=N_samples)

fig = animatedBarPlot(df_plot, y_label=y_label, speed=0.4, title=title)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# <div>                            <div id="32535079-830c-411e-84a4-32185721c8fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("32535079-830c-411e-84a4-32185721c8fd")) {                    Plotly.newPlot(                        "32535079-830c-411e-84a4-32185721c8fd",                        [{"alignmentgroup":"True","hovertemplate":"movie=%{x}<br>month=2015-06<br>Avg. monthly box office revenue=%{y}<extra></extra>","ids":["Avengers: Infinity War"],"legendgroup":"Avengers: Infinity War","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Avengers: Infinity War","offsetgroup":"Avengers: Infinity War","orientation":"v","showlegend":true,"textposition":"auto","x":["Avengers: Infinity War"],"xaxis":"x","y":[0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"movie=%{x}<br>month=2015-06<br>Avg. monthly box office revenue=%{y}<extra></extra>","ids":["Bohemian Rhapsody"],"legendgroup":"Bohemian Rhapsody","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Bohemian Rhapsody","offsetgroup":"Bohemian Rhapsody","orientation":"v","showlegend":true,"textposition":"auto","x":["Bohemian Rhapsody"],"xaxis":"x","y":[0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"movie=%{x}<br>month=2015-06<br>Avg. monthly box office revenue=%{y}<extra></extra>","ids":["Deadpool"],"legendgroup":"Deadpool","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Deadpool","offsetgroup":"Deadpool","orientation":"v","showlegend":true,"textposition":"auto","x":["Deadpool"],"xaxis":"x","y":[0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"movie=%{x}<br>month=2015-06<br>Avg. monthly box office revenue=%{y}<extra></extra>","ids":["Despicable Me 3"],"legendgroup":"Despicable Me 3","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Despicable Me 3","offsetgroup":"Despicable Me 3","orientation":"v","showlegend":true,"textposition":"auto","x":["Despicable Me 3"],"xaxis":"x","y":[0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"movie=%{x}<br>month=2015-06<br>Avg. monthly box office revenue=%{y}<extra></extra>","ids":["Fantastic Beasts and Where to Find Them"],"legendgroup":"Fantastic Beasts and Where to Find Them","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Fantastic Beasts and Where to Find Them","offsetgroup":"Fantastic Beasts and Where to Find Them","orientation":"v","showlegend":true,"textposition":"auto","x":["Fantastic Beasts and Where to Find Them"],"xaxis":"x","y":[0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"movie=%{x}<br>month=2015-06<br>Avg. monthly box office revenue=%{y}<extra></extra>","ids":["Jurassic World"],"legendgroup":"Jurassic World","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Jurassic World","offsetgroup":"Jurassic World","orientation":"v","showlegend":true,"textposition":"auto","x":["Jurassic World"],"xaxis":"x","y":[514374125.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"movie=%{x}<br>month=2015-06<br>Avg. monthly box office revenue=%{y}<extra></extra>","ids":["Rogue One"],"legendgroup":"Rogue One","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Rogue One","offsetgroup":"Rogue One","orientation":"v","showlegend":true,"textposition":"auto","x":["Rogue One"],"xaxis":"x","y":[0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"movie=%{x}<br>month=2015-06<br>Avg. monthly box office revenue=%{y}<extra></extra>","ids":["Sonic the Hedgehog"],"legendgroup":"Sonic the Hedgehog","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Sonic the Hedgehog","offsetgroup":"Sonic the Hedgehog","orientation":"v","showlegend":true,"textposition":"auto","x":["Sonic the Hedgehog"],"xaxis":"x","y":[0],"yaxis" ...

# %%
df_sample.groupby('movie').sum()
# Out:
#                                          rank        daily  theaters
# movie
# Avengers: Infinity War                   2399  678815482.0    240842
# Bohemian Rhapsody                        2845  216303339.0    241573
# Deadpool                                 1470  363042311.0    206822
# Despicable Me 3                          3167  264624300.0    248423
# Fantastic Beasts and Where to Find Them  2619  234037575.0    183213
# Jurassic World                           2336  652197981.0    253875
# Rogue One                                2415  334201140.0    243878
# Sonic the Hedgehog                        106  146066470.0    135100
# Spider-Man: Far from Home                 745  220159104.0    195496
# Star Wars: Episode VIII - The Last Jedi  2247  620181382.0    197295

# %%
y_label = 'sentiment'
df_sentiment_wrangled = wrangleData(df_Quotebank)
attribute = 'scaledBERT_score'
N_samples = 10
title = 'Accumulated BERT sentiment across time'

df_plot, df_sample= createPlotDF(df_sentiment_wrangled, attribute=attribute, y_label=y_label, N_samples=N_samples)

fig = animatedBarPlot(df_plot, y_label=y_label, speed=0.4, title=title)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# <div>                            <div id="9e397075-8292-4cec-9c94-66b54caa9208" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e397075-8292-4cec-9c94-66b54caa9208")) {                    Plotly.newPlot(                        "9e397075-8292-4cec-9c94-66b54caa9208",                        [{"alignmentgroup":"True","hovertemplate":"movie=%{x}<br>month=2015-01<br>Avg. monthly sentiment=%{y}<extra></extra>","ids":["Avengers: Age of Ultron"],"legendgroup":"Avengers: Age of Ultron","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Avengers: Age of Ultron","offsetgroup":"Avengers: Age of Ultron","orientation":"v","showlegend":true,"textposition":"auto","x":["Avengers: Age of Ultron"],"xaxis":"x","y":[14.510559853229498],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"movie=%{x}<br>month=2015-01<br>Avg. monthly sentiment=%{y}<extra></extra>","ids":["Avengers: Infinity War"],"legendgroup":"Avengers: Infinity War","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Avengers: Infinity War","offsetgroup":"Avengers: Infinity War","orientation":"v","showlegend":true,"textposition":"auto","x":["Avengers: Infinity War"],"xaxis":"x","y":[0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"movie=%{x}<br>month=2015-01<br>Avg. monthly sentiment=%{y}<extra></extra>","ids":["Black Panther"],"legendgroup":"Black Panther","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Black Panther","offsetgroup":"Black Panther","orientation":"v","showlegend":true,"textposition":"auto","x":["Black Panther"],"xaxis":"x","y":[0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"movie=%{x}<br>month=2015-01<br>Avg. monthly sentiment=%{y}<extra></extra>","ids":["Captain America: Civil War"],"legendgroup":"Captain America: Civil War","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Captain America: Civil War","offsetgroup":"Captain America: Civil War","orientation":"v","showlegend":true,"textposition":"auto","x":["Captain America: Civil War"],"xaxis":"x","y":[0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"movie=%{x}<br>month=2015-01<br>Avg. monthly sentiment=%{y}<extra></extra>","ids":["Deadpool"],"legendgroup":"Deadpool","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Deadpool","offsetgroup":"Deadpool","orientation":"v","showlegend":true,"textposition":"auto","x":["Deadpool"],"xaxis":"x","y":[0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"movie=%{x}<br>month=2015-01<br>Avg. monthly sentiment=%{y}<extra></extra>","ids":["Mission: Impossible - Fallout"],"legendgroup":"Mission: Impossible - Fallout","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Mission: Impossible - Fallout","offsetgroup":"Mission: Impossible - Fallout","orientation":"v","showlegend":true,"textposition":"auto","x":["Mission: Impossible - Fallout"],"xaxis":"x","y":[0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"movie=%{x}<br>month=2015-01<br>Avg. monthly sentiment=%{y}<extra></extra>","ids":["Spectre"],"legendgroup":"Spectre","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Spectre","offsetgroup":"Spectre","orientation":"v","showlegend":true,"textposition":"auto","x":["Spectre"],"xaxis":"x","y":[0.07402979032049717],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"movie=%{x}<br>month=2015-01<br>Avg. monthly sentiment=%{y}<extra></extra>","ids":["Spider-Man: Far from Home"],"legendgroup":"Spider-Man: Far from Home","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Spider-Man: Far from Home","offsetgroup":"Spider-Man: Far from Home","orientation":"v","showlegend":true,"textposition":"auto","x":["Spider-Man: Far from Home"],"xaxis":"x","y":[0] ...

# %%
df_sample.groupby('movie').sum()
# Out:
#                                                numOccurrences  shared_ID  \
# movie
# Avengers: Endgame                                        3771   13470112
# Black Panther                                            3084   11436103
# Captain America: Civil War                               1952    7770356
# Deadpool                                                  882    2273567
# Mission: Impossible - Fallout                            5360   20014090
# Star Wars: Episode IX - The Rise of Skywalker            4579   14944474
# Star Wars: Episode VII - The Force Awakens               6112   20099487
# Thor: Ragnarok                                           4335   15447656
#
#                                                AFINN_score  VADER_score  \
# movie
# Avengers: Endgame                               -32.499940     662.9563
# Black Panther                                   165.577930     744.2865
# Captain America: Civil War                      -49.537743    -257.8374
# Deadpool                                         46.590351     202.3015
# Mission: Impossible - Fallout                   251.324423    1240.7229
# Star Wars: Episode IX - The Rise of Skywalker   241.296114    -190.5125
# Star Wars: Episode VII - The Force Awakens      311.261760    -574.2501
# Thor: Ragnarok                                  233.640981    1084.1368
#
#                                                posBERT_score  scaledBERT_score
# movie
# Avengers: Endgame                                1554.118572        327.086960
# Black Panther                                    1593.061993        693.228804
# Captain America: Civil War                        926.153384        287.875669
# Deadpool                                          334.373356         28.352087
# Mission: Impossible - Fallout                    2552.253882        773.122672
# Star Wars: Episode IX - The Rise of Skywalker    2250.951311        877.638598
# Star Wars: Episode VII - The Force Awakens       3049.152283       1250.200548
# Thor: Ragnarok                                   2190.180933        934.852559
